# %%
import pandas as pd
from datetime import timedelta
from IPython.display import HTML, display

# %%
date = pd.datetime.today() - timedelta(days=30)
org = 'jupyterhub'
repo = 'zero-to-jupyterhub-k8s'

# %%
# Parameters
org = "jupyterhub"
repo = "jupyterhub"
date = "2019-01-19"

# %%
# Definition of a stale issue/PR (how many days since last updated)
date = pd.to_datetime(date)
stale_days = 30
date_stale = date - timedelta(days=stale_days)

# %% [markdown]
# # Opened and Closed Issues and PRs
#
# This report shows opened and closed issues / PRs over the last 30 days, with a
# particular focus on items that haven't had a lot of discussion, or that have
# been opened by people who aren't team-members. The goal of this page is to make
# it easier to spot places where some input would be appreciated!

# %% [markdown]
# # Imports

# %%
import pandas as pd
from subprocess import run, PIPE
from watchtower import issues_
from glob import glob
import os.path as op
import shutil as sh
import sys
sys.path.append('../../scripts/')

# %% [markdown]
# ## styling functions

# %%
def highlight_rows(val):
    """Highlights cells pertaining to non-members and w/ no comments"""
    disp = ''
    if val == 0 or val == "NONE":
        disp += 'background-color: #f7b7b7'
    elif val == "FIRST_TIME_CONTRIBUTOR":
        disp += 'background-color: red'
    return disp

def make_clickable(val):
    # target _blank to open new window
    return '<a target="_blank" href="{}">{}</a>'.format(val, val)

def print_html(msg):
    display(HTML('<h2 style="padding-left: 1em;">{}</h2>'.format(msg)))
    
pd.options.display.max_colwidth = 200

# %% [markdown]
# ## Load data

# %%
# Issues
issues = issues_.load_issues(org, repo)
issues['user'] = issues['user'].map(lambda a: a['login'])

# %% [markdown]
# # New activity

# %% [markdown]
# ## Opened issues
#
# without responses in red

# %%
opened = issues.query('created_at > @date')
opened_issues = opened[opened['pull_request'].isna()]
opened_issues['closed'] = ~pd.isnull(opened_issues['closed_at'])
# Out:
# /home/choldgraf/anaconda/envs/dev/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
print_html('Opened issues: {}'.format(len(opened_issues)))
# Out:
# <h2 style="padding-left: 1em;">Opened issues: 25</h2>

# %%
opened_issues[['user', 'author_association', 'comments', 'closed', 'html_url']]\
    .sort_values(['closed', 'comments']).style.applymap(highlight_rows).format({'html_url': make_clickable}).hide_index()
# Out:
# <style  type="text/css" >
#     #T_849988c6_3400_11e9_b60e_54ee75e0f62drow0_col1 {
#             background-color:  #f7b7b7;
#         }    #T_849988c6_3400_11e9_b60e_54ee75e0f62drow0_col2 {
#             background-color:  #f7b7b7;
#         }    #T_849988c6_3400_11e9_b60e_54ee75e0f62drow0_col3 {
#             background-color:  #f7b7b7;
#         }    #T_849988c6_3400_11e9_b60e_54ee75e0f62drow1_col2 {
#             background-color:  #f7b7b7;
#         }    #T_849988c6_3400_11e9_b60e_54ee75e0f62drow1_col3 {
#             background-color:  #f7b7b7;
#         }    #T_849988c6_3400_11e9_b60e_54ee75e0f62drow2_col1 {
#             background-color:  #f7b7b7;
#         }    #T_849988c6_3400_11e9_b60e_54ee75e0f62drow2_col3 {
#             background-color:  #f7b7b7;
#         }    #T_849988c6_3400_11e9_b60e_54ee75e0f62drow3_col1 {
#             background-color:  #f7b7b7;
#         }    #T_849988c6_3400_11e9_b60e_54ee75e0f62drow3_col3 {
#             background-color:  #f7b7b7;
#         }    #T_849988c6_3400_11e9_b60e_54ee75e0f62drow4_col1 {
#             background-color:  #f7b7b7;
#         }    #T_849988c6_3400_11e9_b60e_54ee75e0f62drow4_col3 {
#             background-color:  #f7b7b7;
#         }    #T_849988c6_3400_11e9_b60e_54ee75e0f62drow5_col1 {
#             background-color:  #f7b7b7;
#         }    #T_849988c6_3400_11e9_b60e_54ee75e0f62drow5_col3 {
#             background-color:  #f7b7b7;
#         }    #T_849988c6_3400_11e9_b60e_54ee75e0f62drow6_col1 {
#             background-color:  #f7b7b7;
#         }    #T_849988c6_3400_11e9_b60e_54ee75e0f62drow6_col3 {
#             background-color:  #f7b7b7;
#         }    #T_849988c6_3400_11e9_b60e_54ee75e0f62drow7_col1 {
#             background-color:  #f7b7b7;
#         }    #T_849988c6_3400_11e9_b60e_54ee75e0f62drow7_col3 {
#             background-color:  #f7b7b7;
#         }    #T_849988c6_3400_11e9_b60e_54ee75e0f62drow8_col1 {
#             background-color:  #f7b7b7;
#         }    #T_849988c6_3400_11e9_b60e_54ee75e0f62drow8_col3 {
#             background-color:  #f7b7b7;
#         }    #T_849988c6_3400_11e9_b60e_54ee75e0f62drow9_col1 {
#             background-color:  #f7b7b7;
#         }    #T_849988c6_3400_11e9_b60e_54ee75e0f62drow9_col3 {
#             background-color:  #f7b7b7;
#         }    #T_849988c6_3400_11e9_b60e_54ee75e0f62drow10_col1 {
#             background-color:  #f7b7b7;
#         }    #T_849988c6_3400_11e9_b60e_54ee75e0f62drow10_col3 {
#             background-color:  #f7b7b7;
#         }    #T_849988c6_3400_11e9_b60e_54ee75e0f62drow11_col1 {
#             background-color:  #f7b7b7;
#         }    #T_849988c6_3400_11e9_b60e_54ee75e0f62drow11_col3 {
#             background-color:  #f7b7b7;
#         }    #T_849988c6_3400_11e9_b60e_54ee75e0f62drow12_col1 {
#             background-color:  #f7b7b7;
#         }    #T_849988c6_3400_11e9_b60e_54ee75e0f62drow12_col3 {
#             background-color:  #f7b7b7;
#         }    #T_849988c6_3400_11e9_b60e_54ee75e0f62drow13_col3 {
#             background-color:  #f7b7b7;
#         }    #T_849988c6_3400_11e9_b60e_54ee75e0f62drow14_col1 {
#             background-color:  #f7b7b7;
#         }    #T_849988c6_3400_11e9_b60e_54ee75e0f62drow14_col3 {
#             background-color:  #f7b7b7;
#         }    #T_849988c6_3400_11e9_b60e_54ee75e0f62drow15_col1 {
#             background-color:  #f7b7b7;
#         }    #T_849988c6_3400_11e9_b60e_54ee75e0f62drow15_col2 {
#             background-color:  #f7b7b7;
#         }    #T_849988c6_3400_11e9_b60e_54ee75e0f62drow18_col1 {
#             background-color:  #f7b7b7;
#         }    #T_849988c6_3400_11e9_b60e_54ee75e0f62drow19_col1 {
#             background-color:  #f7b7b7;
#         }    #T_849988c6_3400_11e9_b60e_54ee75e0f62drow20_col1 {
#             background-color:  #f7b7b7;
#         }    #T_849988c6_3400_11e9_b60e_54ee75e0f62drow21_col1 {
#             background-color:  #f7b7b7;
#         }    #T_849988c6_3400_11e9_b60e_54ee75e0f62drow22_col1 {
#             background-color:  #f7b7b7;
#         }    #T_849988c6_3400_11e9_b60e_54ee75e0f62drow23_col1 {
#             background-color:  #f7b7b7;
#         }</style><table id="T_849988c6_3400_11e9_b60e_54ee75e0f62d" ><thead>    <tr>        <th class="col_heading level0 col0" >user</th>        <th class="col_heading level0 col1" >author_association</th>        <th class="col_heading level0 col2" >comments</th>        <th class="col_heading level0 col3" >closed</th>        <th class="col_heading level0 col4" >html_url</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_849988c6_3400_11e9_b60e_54ee75e0f62drow0_col0" class="data row0 col0" >mattvw</td>
#                         <td id="T_849988c6_3400_11e9_b60e_54ee75e0f62drow0_col1" class="data row0 col1" >NONE</td>
#                         <td id="T_849988c6_3400_11e9_b60e_54ee75e0f62drow0_col2" class="data row0 col2" >0</td>
#                         <td id="T_849988c6_3400_11e9_b60e_54ee75e0f62drow0_col3" class="data row0 col3" >False</td>
#                         <td id="T_849988c6_3400_11e9_b60e_54ee75e0f62drow0_col4" class="data row0 col4" ><a target="_blank" href="https://github.com/jupyterhub/jupyterhub/issues/2421">https://github.com/jupyterhub/jupyterhub/issues/2421</a></td>
#             </tr>
#             <tr>
#                                 <td id="T_849988c6_3400_11e9_b60e_54ee75e0f62drow1_col0" class="data row1 col0" >consideRatio</td>
#                         <td id="T_849988c6_3400_11e9_b60e_54ee75e0f62drow1_col1" class="data row1 col1" >MEMBER</td>
#                         <td id="T_849988c6_3400_11e9_b60e_54ee75e0f62drow1_col2" class="data row1 col2" >0</td>
#                         <td id="T_849988c6_3400_11e9_b60e_54ee75e0f62drow1_col3" class="data row1 col3" >False</td>
#                         <td id="T_849988c6_3400_11e9_b60e_54ee75e0f62drow1_col4" class="data row1 col4" ><a target="_blank" href="https://github.com/jupyterhub/jupyterhub/issues/2403">https://github.com/jupyterhub/jupyterhub/issues/2403</a></td>
#             </tr>
#             <tr>
#                                 <td id="T_849988c6_3400_11e9_b60e_54ee75e0f62drow2_col0" class="data row2 col0" >palashSharma17</td>
#                         <td id="T_849988c6_3400_11e9_b60e_54ee75e0f62drow2_col1" class="data row2 col1" >NONE</td>
#                         <td id="T_849988c6_3400_11e9_b60e_54ee75e0f62drow2_col2" class="data row2 col2" >1</td>
#                         <td id="T_849988c6_3400_11e9_b60e_54ee75e0f62drow2_col3" class="data row2 col3" >False</td>
#                         <td id="T_849988c6_3400_11e9_b60e_54ee75e0f62drow2_col4" class="data row2 col4" ><a target="_blank" href="https://github.com/jupyterhub/jupyterhub/issues/2420">https://github.com/jupyterhub/jupyterhub/issues/2420</a></td>
#             </tr>
#             <tr>
#                                 <td id="T_849988c6_3400_11e9_b60e_54ee75e0f62drow3_col0" class="data row3 col0" >mrocklin</td>
#                         <td id="T_849988c6_3400_11e9_b60e_54ee75e0f62drow3_col1" class="data row3 col1" >NONE</td>
#                         <td id="T_849988c6_3400_11e9_b60e_54ee75e0f62drow3_col2" class="data row3 col2" >1</td>
#                         <td id="T_849988c6_3400_11e9_b60e_54ee75e0f62drow3_col3" class="data row3 col3" >False</td>
#                         <td id="T_849988c6_3400_11e9_b60e_54ee75e0f62drow3_col4" class="data row3 col4" ><a target="_blank" href="https://github.com/jupyterhub/jupyterhub/issues/2394">https://github.com/jupyterhub/jupyterhub/issues/2394</a></td>
#             </tr>
#             <tr>
#                                 <td id="T_849988c6_3400_11e9_b60e_54ee75e0f62drow4_col0" class="data row4 col0" >MichWeb75</td>
#                         <td id="T_849988c6_3400_11e9_b60e_54ee75e0f62drow4_col1" class="data row4 col1" >NONE</td>
#                         <td id="T_849988c6_3400_11e9_b60e_54ee75e0f62drow4_col2" class="data row4 col2" >1</td>
#                         <td id="T_849988c6_3400_11e9_b60e_54ee75e0f62drow4_col3" class="data row4 col3" >False</td>
#                         <td id="T_849988c6_3400_11e9_b60e_54ee75e0f62drow4_col4" class="data row4 col4" >

# %% [markdown]
# ## Closed issues

# %%
closed = issues.query('closed_at > @date')
closed_issues = closed[closed['pull_request'].isna()]

# %%
closed_issues[['user', 'author_association', 'comments', 'html_url']]\
    .sort_values(['comments']).style.applymap(highlight_rows).format({'html_url': make_clickable}).hide_index()
# Out:
# <style  type="text/css" >
#     #T_84eff120_3400_11e9_b60e_54ee75e0f62drow0_col1 {
#             background-color:  #f7b7b7;
#         }    #T_84eff120_3400_11e9_b60e_54ee75e0f62drow0_col2 {
#             background-color:  #f7b7b7;
#         }    #T_84eff120_3400_11e9_b60e_54ee75e0f62drow3_col1 {
#             background-color:  #f7b7b7;
#         }    #T_84eff120_3400_11e9_b60e_54ee75e0f62drow4_col1 {
#             background-color:  #f7b7b7;
#         }    #T_84eff120_3400_11e9_b60e_54ee75e0f62drow5_col1 {
#             background-color:  #f7b7b7;
#         }    #T_84eff120_3400_11e9_b60e_54ee75e0f62drow6_col1 {
#             background-color:  #f7b7b7;
#         }    #T_84eff120_3400_11e9_b60e_54ee75e0f62drow7_col1 {
#             background-color:  #f7b7b7;
#         }    #T_84eff120_3400_11e9_b60e_54ee75e0f62drow8_col1 {
#             background-color:  #f7b7b7;
#         }    #T_84eff120_3400_11e9_b60e_54ee75e0f62drow9_col1 {
#             background-color:  #f7b7b7;
#         }    #T_84eff120_3400_11e9_b60e_54ee75e0f62drow10_col1 {
#             background-color:  #f7b7b7;
#         }    #T_84eff120_3400_11e9_b60e_54ee75e0f62drow11_col1 {
#             background-color:  #f7b7b7;
#         }    #T_84eff120_3400_11e9_b60e_54ee75e0f62drow12_col1 {
#             background-color:  #f7b7b7;
#         }</style><table id="T_84eff120_3400_11e9_b60e_54ee75e0f62d" ><thead>    <tr>        <th class="col_heading level0 col0" >user</th>        <th class="col_heading level0 col1" >author_association</th>        <th class="col_heading level0 col2" >comments</th>        <th class="col_heading level0 col3" >html_url</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_84eff120_3400_11e9_b60e_54ee75e0f62drow0_col0" class="data row0 col0" >jameshgrn</td>
#                         <td id="T_84eff120_3400_11e9_b60e_54ee75e0f62drow0_col1" class="data row0 col1" >NONE</td>
#                         <td id="T_84eff120_3400_11e9_b60e_54ee75e0f62drow0_col2" class="data row0 col2" >0</td>
#                         <td id="T_84eff120_3400_11e9_b60e_54ee75e0f62drow0_col3" class="data row0 col3" ><a target="_blank" href="https://github.com/jupyterhub/jupyterhub/issues/2391">https://github.com/jupyterhub/jupyterhub/issues/2391</a></td>
#             </tr>
#             <tr>
#                                 <td id="T_84eff120_3400_11e9_b60e_54ee75e0f62drow1_col0" class="data row1 col0" >consideRatio</td>
#                         <td id="T_84eff120_3400_11e9_b60e_54ee75e0f62drow1_col1" class="data row1 col1" >MEMBER</td>
#                         <td id="T_84eff120_3400_11e9_b60e_54ee75e0f62drow1_col2" class="data row1 col2" >1</td>
#                         <td id="T_84eff120_3400_11e9_b60e_54ee75e0f62drow1_col3" class="data row1 col3" ><a target="_blank" href="https://github.com/jupyterhub/jupyterhub/issues/2396">https://github.com/jupyterhub/jupyterhub/issues/2396</a></td>
#             </tr>
#             <tr>
#                                 <td id="T_84eff120_3400_11e9_b60e_54ee75e0f62drow2_col0" class="data row2 col0" >consideRatio</td>
#                         <td id="T_84eff120_3400_11e9_b60e_54ee75e0f62drow2_col1" class="data row2 col1" >MEMBER</td>
#                         <td id="T_84eff120_3400_11e9_b60e_54ee75e0f62drow2_col2" class="data row2 col2" >1</td>
#                         <td id="T_84eff120_3400_11e9_b60e_54ee75e0f62drow2_col3" class="data row2 col3" ><a target="_blank" href="https://github.com/jupyterhub/jupyterhub/issues/2388">https://github.com/jupyterhub/jupyterhub/issues/2388</a></td>
#             </tr>
#             <tr>
#                                 <td id="T_84eff120_3400_11e9_b60e_54ee75e0f62drow3_col0" class="data row3 col0" >krishdey</td>
#                         <td id="T_84eff120_3400_11e9_b60e_54ee75e0f62drow3_col1" class="data row3 col1" >NONE</td>
#                         <td id="T_84eff120_3400_11e9_b60e_54ee75e0f62drow3_col2" class="data row3 col2" >1</td>
#                         <td id="T_84eff120_3400_11e9_b60e_54ee75e0f62drow3_col3" class="data row3 col3" ><a target="_blank" href="https://github.com/jupyterhub/jupyterhub/issues/2408">https://github.com/jupyterhub/jupyterhub/issues/2408</a></td>
#             </tr>
#             <tr>
#                                 <td id="T_84eff120_3400_11e9_b60e_54ee75e0f62drow4_col0" class="data row4 col0" >palashSharma17</td>
#                         <td id="T_84eff120_3400_11e9_b60e_54ee75e0f62drow4_col1" class="data row4 col1" >NONE</td>
#                         <td id="T_84eff120_3400_11e9_b60e_54ee75e0f62drow4_col2" class="data row4 col2" >2</td>
#                         <td id="T_84eff120_3400_11e9_b60e_54ee75e0f62drow4_col3" class="data row4 col3" ><a target="_blank" href="https://github.com/jupyterhub/jupyterhub/issues/2400">https://github.com/jupyterhub/jupyterhub/issues/2400</a></td>
#             </tr>
#             <tr>
#                                 <td id="T_84eff120_3400_11e9_b60e_54ee75e0f62drow5_col0" class="data row5 col0" >marvin-solano</td>
#                         <td id="T_84eff120_3400_11e9_b60e_54ee75e0f62drow5_col1" class="data row5 col1" >NONE</td>
#                         <td id="T_84eff120_3400_11e9_b60e_54ee75e0f62drow5_col2" class="data row5 col2" >2</td>
#                         <td id="T_84eff120_3400_11e9_b60e_54ee75e0f62drow5_col3" class="data row5 col3" ><a target="_blank" href="https://github.com/jupyterhub/jupyterhub/issues/2348">https://github.com/jupyterhub/jupyterhub/issues/2348</a></td>
#             </tr>
#             <tr>
#                                 <td id="T_84eff120_3400_11e9_b60e_54ee75e0f62drow6_col0" class="data row6 col0" >BoPeng</td>
#                         <td id="T_84eff120_3400_11e9_b60e_54ee75e0f62drow6_col1" class="data row6 col1" >NONE</td>
#                         <td id="T_84eff120_3400_11e9_b60e_54ee75e0f62drow6_col2" class="data row6 col2" >2</td>
#                         <td id="T_84eff120_3400_11e9_b60e_54ee75e0f62drow6_col3" class="data row6 col3" ><a target="_blank" href="https://github.com/jupyterhub/jupyterhub/issues/2409">https://github.com/jupyterhub/jupyterhub/issues/2409</a></td>
#             </tr>
#             <tr>
#                                 <td id="T_84eff120_3400_11e9_b60e_54ee75e0f62drow7_col0" class="data row7 col0" >sidebo</td>
#                         <td id="T_84eff120_3400_11e9_b60e_54ee75e0f62drow7_col1" class="data row7 col1" >NONE</td>
#                         <td id="T_84eff120_3400_11e9_b60e_54ee75e0f62drow7_col2" class="data row7 col2" >2</td>
#                         <td id="T_84eff120_3400_11e9_b60e_54ee75e0f62drow7_col3" class="data row7 col3" ><a target="_blank" href="https://github.com/jupyterhub/jupyterhub/issues/2232">https://github.com/jupyterhub/jupyterhub/issues/2232</a></td>
#             </tr>
#             <tr>
#                                 <td id="T_84eff120_3400_11e9_b60e_54ee75e0f62drow8_col0" class="data row8 col0" >palashSharma17</td>
#                         <td id="T_84eff120_3400_11e9_b60e_54ee75e0f62drow8_col1" class="data row8 col1" >NONE</td>
#                         <td id="T_84eff120_3400_11e9_b60e_54ee75e0f62drow8_col2" class="data row8 col2" >3</td>
#                         <td id="T_84eff120_3400_11e9_b60e_54ee75e0f62drow8_col3" class="data row8 col3" ><a target="_blank" href="https://github.com/jupyterhub/jupyterhub/issues/2395">https://github.com/jupyterhub/jupyterhub/issues/2395</a></td>
#             </tr>
#             <tr>
#                                 <td id="T_84eff120_3400_11e9_b60e_54ee75e0f62drow9_col0" class="data row9 col0" >1kastner</td>
#                         <td id="T_84eff120_3400_11e9_b60e_54ee75e0f62drow9_col1" class="data row9 col1" >NONE</td>
#                         <td id="T_84eff120_3400_11e9_b60e_54ee75e0f62drow9_col2" class="data row9 col2" >3</td>
#                         <td id="T_84eff120_3400_11e9_b60e_54ee75e0f62drow9_col3" class="data row9 col3" ><a target="_blank" href="https://github.com/jupyterhub/jupyterhub/issues/2412">https://github.com/jupyterhub/jupyterhub/issues/2412</a></td>
#             </tr>

# %%
print_html('Closed issues: {}'.format(len(closed_issues)))
# Out:
# <h2 style="padding-left: 1em;">Closed issues: 14</h2>

# %% [markdown]
# ## Opened PRs
#
# without responses in red

# %%
opened_prs = opened[~opened['pull_request'].isna()]
opened_prs['closed'] = ~pd.isnull(opened_prs['closed_at'])

closed_prs = closed[~closed['pull_request'].isna()]
# Out:
# /home/choldgraf/anaconda/envs/dev/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
print_html('Opened PRs: {}'.format(len(opened_prs)))
# Out:
# <h2 style="padding-left: 1em;">Opened PRs: 8</h2>

# %%
opened_prs[['user', 'author_association', 'comments', 'closed', 'html_url']]\
    .sort_values(['closed', 'comments']).style.applymap(highlight_rows).format({'html_url': make_clickable}).hide_index()
# Out:
# <style  type="text/css" >
#     #T_855134da_3400_11e9_b60e_54ee75e0f62drow0_col2 {
#             background-color:  #f7b7b7;
#         }    #T_855134da_3400_11e9_b60e_54ee75e0f62drow0_col3 {
#             background-color:  #f7b7b7;
#         }    #T_855134da_3400_11e9_b60e_54ee75e0f62drow1_col2 {
#             background-color:  #f7b7b7;
#         }    #T_855134da_3400_11e9_b60e_54ee75e0f62drow2_col2 {
#             background-color:  #f7b7b7;
#         }    #T_855134da_3400_11e9_b60e_54ee75e0f62drow3_col2 {
#             background-color:  #f7b7b7;
#         }</style><table id="T_855134da_3400_11e9_b60e_54ee75e0f62d" ><thead>    <tr>        <th class="col_heading level0 col0" >user</th>        <th class="col_heading level0 col1" >author_association</th>        <th class="col_heading level0 col2" >comments</th>        <th class="col_heading level0 col3" >closed</th>        <th class="col_heading level0 col4" >html_url</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_855134da_3400_11e9_b60e_54ee75e0f62drow0_col0" class="data row0 col0" >minrk</td>
#                         <td id="T_855134da_3400_11e9_b60e_54ee75e0f62drow0_col1" class="data row0 col1" >MEMBER</td>
#                         <td id="T_855134da_3400_11e9_b60e_54ee75e0f62drow0_col2" class="data row0 col2" >0</td>
#                         <td id="T_855134da_3400_11e9_b60e_54ee75e0f62drow0_col3" class="data row0 col3" >False</td>
#                         <td id="T_855134da_3400_11e9_b60e_54ee75e0f62drow0_col4" class="data row0 col4" ><a target="_blank" href="https://github.com/jupyterhub/jupyterhub/pull/2418">https://github.com/jupyterhub/jupyterhub/pull/2418</a></td>
#             </tr>
#             <tr>
#                                 <td id="T_855134da_3400_11e9_b60e_54ee75e0f62drow1_col0" class="data row1 col0" >minrk</td>
#                         <td id="T_855134da_3400_11e9_b60e_54ee75e0f62drow1_col1" class="data row1 col1" >MEMBER</td>
#                         <td id="T_855134da_3400_11e9_b60e_54ee75e0f62drow1_col2" class="data row1 col2" >0</td>
#                         <td id="T_855134da_3400_11e9_b60e_54ee75e0f62drow1_col3" class="data row1 col3" >True</td>
#                         <td id="T_855134da_3400_11e9_b60e_54ee75e0f62drow1_col4" class="data row1 col4" ><a target="_blank" href="https://github.com/jupyterhub/jupyterhub/pull/2413">https://github.com/jupyterhub/jupyterhub/pull/2413</a></td>
#             </tr>
#             <tr>
#                                 <td id="T_855134da_3400_11e9_b60e_54ee75e0f62drow2_col0" class="data row2 col0" >minrk</td>
#                         <td id="T_855134da_3400_11e9_b60e_54ee75e0f62drow2_col1" class="data row2 col1" >MEMBER</td>
#                         <td id="T_855134da_3400_11e9_b60e_54ee75e0f62drow2_col2" class="data row2 col2" >0</td>
#                         <td id="T_855134da_3400_11e9_b60e_54ee75e0f62drow2_col3" class="data row2 col3" >True</td>
#                         <td id="T_855134da_3400_11e9_b60e_54ee75e0f62drow2_col4" class="data row2 col4" ><a target="_blank" href="https://github.com/jupyterhub/jupyterhub/pull/2404">https://github.com/jupyterhub/jupyterhub/pull/2404</a></td>
#             </tr>
#             <tr>
#                                 <td id="T_855134da_3400_11e9_b60e_54ee75e0f62drow3_col0" class="data row3 col0" >minrk</td>
#                         <td id="T_855134da_3400_11e9_b60e_54ee75e0f62drow3_col1" class="data row3 col1" >MEMBER</td>
#                         <td id="T_855134da_3400_11e9_b60e_54ee75e0f62drow3_col2" class="data row3 col2" >0</td>
#                         <td id="T_855134da_3400_11e9_b60e_54ee75e0f62drow3_col3" class="data row3 col3" >True</td>
#                         <td id="T_855134da_3400_11e9_b60e_54ee75e0f62drow3_col4" class="data row3 col4" ><a target="_blank" href="https://github.com/jupyterhub/jupyterhub/pull/2414">https://github.com/jupyterhub/jupyterhub/pull/2414</a></td>
#             </tr>
#             <tr>
#                                 <td id="T_855134da_3400_11e9_b60e_54ee75e0f62drow4_col0" class="data row4 col0" >dtaniwaki</td>
#                         <td id="T_855134da_3400_11e9_b60e_54ee75e0f62drow4_col1" class="data row4 col1" >CONTRIBUTOR</td>
#                         <td id="T_855134da_3400_11e9_b60e_54ee75e0f62drow4_col2" class="data row4 col2" >2</td>
#                         <td id="T_855134da_3400_11e9_b60e_54ee75e0f62drow4_col3" class="data row4 col3" >True</td>
#                         <td id="T_855134da_3400_11e9_b60e_54ee75e0f62drow4_col4" class="data row4 col4" ><a target="_blank" href="https://github.com/jupyterhub/jupyterhub/pull/2387">https://github.com/jupyterhub/jupyterhub/pull/2387</a></td>
#             </tr>
#             <tr>
#                                 <td id="T_855134da_3400_11e9_b60e_54ee75e0f62drow5_col0" class="data row5 col0" >rkdarst</td>
#                         <td id="T_855134da_3400_11e9_b60e_54ee75e0f62drow5_col1" class="data row5 col1" >CONTRIBUTOR</td>
#                         <td id="T_855134da_3400_11e9_b60e_54ee75e0f62drow5_col2" class="data row5 col2" >3</td>
#                         <td id="T_855134da_3400_11e9_b60e_54ee75e0f62drow5_col3" class="data row5 col3" >True</td>
#                         <td id="T_855134da_3400_11e9_b60e_54ee75e0f62drow5_col4" class="data row5 col4" ><a target="_blank" href="https://github.com/jupyterhub/jupyterhub/pull/2397">https://github.com/jupyterhub/jupyterhub/pull/2397</a></td>
#             </tr>
#             <tr>
#                                 <td id="T_855134da_3400_11e9_b60e_54ee75e0f62drow6_col0" class="data row6 col0" >consideRatio</td>
#                         <td id="T_855134da_3400_11e9_b60e_54ee75e0f62drow6_col1" class="data row6 col1" >MEMBER</td>
#                         <td id="T_855134da_3400_11e9_b60e_54ee75e0f62drow6_col2" class="data row6 col2" >4</td>
#                         <td id="T_855134da_3400_11e9_b60e_54ee75e0f62drow6_col3" class="data row6 col3" >True</td>
#                         <td id="T_855134da_3400_11e9_b60e_54ee75e0f62drow6_col4" class="data row6 col4" ><a target="_blank" href="https://github.com/jupyterhub/jupyterhub/pull/2402">https://github.com/jupyterhub/jupyterhub/pull/2402</a></td>
#             </tr>
#             <tr>
#                                 <td id="T_855134da_3400_11e9_b60e_54ee75e0f62drow7_col0" class="data row7 col0" >consideRatio</td>
#                         <td id="T_855134da_3400_11e9_b60e_54ee75e0f62drow7_col1" class="data row7 col1" >MEMBER</td>
#                         <td id="T_855134da_3400_11e9_b60e_54ee75e0f62drow7_col2" class="data row7 col2" >8</td>
#                         <td id="T_855134da_3400_11e9_b60e_54ee75e0f62drow7_col3" class="data row7 col3" >True</td>
#                         <td id="T_855134da_3400_11e9_b60e_54ee75e0f62drow7_col4" class="data row7 col4" ><a target="_blank" href="https://github.com/jupyterhub/jupyterhub/pull/2415">https://github.com/jupyterhub/jupyterhub/pull/2415</a></td>
#             </tr>
#     </tbody></table>

# %%
print_html('Closed PRs: {}'.format(len(closed_prs)))
# Out:
# <h2 style="padding-left: 1em;">Closed PRs: 12</h2>

# %%
closed_prs[['user', 'author_association', 'comments', 'html_url']]\
    .sort_values(['comments']).style.applymap(highlight_rows).format({'html_url': make_clickable}).hide_index()
# Out:
# <style  type="text/css" >
#     #T_858a12b4_3400_11e9_b60e_54ee75e0f62drow0_col2 {
#             background-color:  #f7b7b7;
#         }    #T_858a12b4_3400_11e9_b60e_54ee75e0f62drow1_col2 {
#             background-color:  #f7b7b7;
#         }    #T_858a12b4_3400_11e9_b60e_54ee75e0f62drow2_col2 {
#             background-color:  #f7b7b7;
#         }    #T_858a12b4_3400_11e9_b60e_54ee75e0f62drow3_col2 {
#             background-color:  #f7b7b7;
#         }</style><table id="T_858a12b4_3400_11e9_b60e_54ee75e0f62d" ><thead>    <tr>        <th class="col_heading level0 col0" >user</th>        <th class="col_heading level0 col1" >author_association</th>        <th class="col_heading level0 col2" >comments</th>        <th class="col_heading level0 col3" >html_url</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_858a12b4_3400_11e9_b60e_54ee75e0f62drow0_col0" class="data row0 col0" >minrk</td>
#                         <td id="T_858a12b4_3400_11e9_b60e_54ee75e0f62drow0_col1" class="data row0 col1" >MEMBER</td>
#                         <td id="T_858a12b4_3400_11e9_b60e_54ee75e0f62drow0_col2" class="data row0 col2" >0</td>
#                         <td id="T_858a12b4_3400_11e9_b60e_54ee75e0f62drow0_col3" class="data row0 col3" ><a target="_blank" href="https://github.com/jupyterhub/jupyterhub/pull/2413">https://github.com/jupyterhub/jupyterhub/pull/2413</a></td>
#             </tr>
#             <tr>
#                                 <td id="T_858a12b4_3400_11e9_b60e_54ee75e0f62drow1_col0" class="data row1 col0" >minrk</td>
#                         <td id="T_858a12b4_3400_11e9_b60e_54ee75e0f62drow1_col1" class="data row1 col1" >MEMBER</td>
#                         <td id="T_858a12b4_3400_11e9_b60e_54ee75e0f62drow1_col2" class="data row1 col2" >0</td>
#                         <td id="T_858a12b4_3400_11e9_b60e_54ee75e0f62drow1_col3" class="data row1 col3" ><a target="_blank" href="https://github.com/jupyterhub/jupyterhub/pull/2342">https://github.com/jupyterhub/jupyterhub/pull/2342</a></td>
#             </tr>
#             <tr>
#                                 <td id="T_858a12b4_3400_11e9_b60e_54ee75e0f62drow2_col0" class="data row2 col0" >minrk</td>
#                         <td id="T_858a12b4_3400_11e9_b60e_54ee75e0f62drow2_col1" class="data row2 col1" >MEMBER</td>
#                         <td id="T_858a12b4_3400_11e9_b60e_54ee75e0f62drow2_col2" class="data row2 col2" >0</td>
#                         <td id="T_858a12b4_3400_11e9_b60e_54ee75e0f62drow2_col3" class="data row2 col3" ><a target="_blank" href="https://github.com/jupyterhub/jupyterhub/pull/2404">https://github.com/jupyterhub/jupyterhub/pull/2404</a></td>
#             </tr>
#             <tr>
#                                 <td id="T_858a12b4_3400_11e9_b60e_54ee75e0f62drow3_col0" class="data row3 col0" >minrk</td>
#                         <td id="T_858a12b4_3400_11e9_b60e_54ee75e0f62drow3_col1" class="data row3 col1" >MEMBER</td>
#                         <td id="T_858a12b4_3400_11e9_b60e_54ee75e0f62drow3_col2" class="data row3 col2" >0</td>
#                         <td id="T_858a12b4_3400_11e9_b60e_54ee75e0f62drow3_col3" class="data row3 col3" ><a target="_blank" href="https://github.com/jupyterhub/jupyterhub/pull/2414">https://github.com/jupyterhub/jupyterhub/pull/2414</a></td>
#             </tr>
#             <tr>
#                                 <td id="T_858a12b4_3400_11e9_b60e_54ee75e0f62drow4_col0" class="data row4 col0" >dtaniwaki</td>
#                         <td id="T_858a12b4_3400_11e9_b60e_54ee75e0f62drow4_col1" class="data row4 col1" >CONTRIBUTOR</td>
#                         <td id="T_858a12b4_3400_11e9_b60e_54ee75e0f62drow4_col2" class="data row4 col2" >2</td>
#                         <td id="T_858a12b4_3400_11e9_b60e_54ee75e0f62drow4_col3" class="data row4 col3" ><a target="_blank" href="https://github.com/jupyterhub/jupyterhub/pull/2387">https://github.com/jupyterhub/jupyterhub/pull/2387</a></td>
#             </tr>
#             <tr>
#                                 <td id="T_858a12b4_3400_11e9_b60e_54ee75e0f62drow5_col0" class="data row5 col0" >dtaniwaki</td>
#                         <td id="T_858a12b4_3400_11e9_b60e_54ee75e0f62drow5_col1" class="data row5 col1" >CONTRIBUTOR</td>
#                         <td id="T_858a12b4_3400_11e9_b60e_54ee75e0f62drow5_col2" class="data row5 col2" >2</td>
#                         <td id="T_858a12b4_3400_11e9_b60e_54ee75e0f62drow5_col3" class="data row5 col3" ><a target="_blank" href="https://github.com/jupyterhub/jupyterhub/pull/2375">https://github.com/jupyterhub/jupyterhub/pull/2375</a></td>
#             </tr>
#             <tr>
#                                 <td id="T_858a12b4_3400_11e9_b60e_54ee75e0f62drow6_col0" class="data row6 col0" >rkdarst</td>
#                         <td id="T_858a12b4_3400_11e9_b60e_54ee75e0f62drow6_col1" class="data row6 col1" >CONTRIBUTOR</td>
#                         <td id="T_858a12b4_3400_11e9_b60e_54ee75e0f62drow6_col2" class="data row6 col2" >3</td>
#                         <td id="T_858a12b4_3400_11e9_b60e_54ee75e0f62drow6_col3" class="data row6 col3" ><a target="_blank" href="https://github.com/jupyterhub/jupyterhub/pull/2397">https://github.com/jupyterhub/jupyterhub/pull/2397</a></td>
#             </tr>
#             <tr>
#                                 <td id="T_858a12b4_3400_11e9_b60e_54ee75e0f62drow7_col0" class="data row7 col0" >vilhelmen</td>
#                         <td id="T_858a12b4_3400_11e9_b60e_54ee75e0f62drow7_col1" class="data row7 col1" >CONTRIBUTOR</td>
#                         <td id="T_858a12b4_3400_11e9_b60e_54ee75e0f62drow7_col2" class="data row7 col2" >3</td>
#                         <td id="T_858a12b4_3400_11e9_b60e_54ee75e0f62drow7_col3" class="data row7 col3" ><a target="_blank" href="https://github.com/jupyterhub/jupyterhub/pull/2268">https://github.com/jupyterhub/jupyterhub/pull/2268</a></td>
#             </tr>
#             <tr>
#                                 <td id="T_858a12b4_3400_11e9_b60e_54ee75e0f62drow8_col0" class="data row8 col0" >minrk</td>
#                         <td id="T_858a12b4_3400_11e9_b60e_54ee75e0f62drow8_col1" class="data row8 col1" >MEMBER</td>
#                         <td id="T_858a12b4_3400_11e9_b60e_54ee75e0f62drow8_col2" class="data row8 col2" >4</td>
#                         <td id="T_858a12b4_3400_11e9_b60e_54ee75e0f62drow8_col3" class="data row8 col3" ><a target="_blank" href="https://github.com/jupyterhub/jupyterhub/pull/2346">https://github.com/jupyterhub/jupyterhub/pull/2346</a></td>
#             </tr>
#             <tr>
#                                 <td id="T_858a12b4_3400_11e9_b60e_54ee75e0f62drow9_col0" class="data row9 col0" >consideRatio</td>
#                         <td id="T_858a12b4_3400_11e9_b60e_54ee75e0f62drow9_col1" class="data row9 col1" >MEMBER</td>
#                         <td id="T_858a12b4_3400_11e9_b60e_54ee75e0f62drow9_col2" class="data row9 col2" >4</td>
#                         <td id="T_858a12b4_3400_11e9_b60e_54ee75e0f62drow9_col3" class="data row9 col3" ><a target="_blank" href="https://github.com/jupyterhub/jupyterhub/pull/2402">https://github.com/jupyterhub/jupyterhub/pull/2402</a></td>
#             </tr>
#             <tr>
#                                 <td id="T_858a12b4_3400_11e9_b60e_54ee75e0f62drow10_col0" class="data row10 col0" >Deepakdubey90</td>
#                         <td id="T_858a12b4_3400_11e9_b60e_54ee75e0f62drow10_col1" class="data row10 col1" >CONTRIBUTOR</td>
#                         <td id="T_858a12b4_3400_11e9_b60e_54ee75e0f62drow10_col2" class="data row10 col2" >5</td>
#                         <td id="T_858a12b4_3400_11e9_b60e_54ee75e0f62drow10_col3" class="data row10 col3" ><a target="_blank" href="https://github.com/jupyterhub/jupyterhub/pull/2330">https://github.com/jupyterhub/jupyterhub/pull/2330</a></td>
#             </tr>
#             <tr>
#                                 <td id="T_858a12b4_3400_11e9_b60e_54ee75e0f62drow11_col0" class="data row11 col0" >consideRatio</td>
#                         <td id="T_858a12b4_3400_11e9_b60e_54ee75e0f62drow1

# %% [markdown]
# # State of repo
#
# ## Stale issues

# %%
stale_issues = issues.query('updated_at < @date_stale')
stale_issues = stale_issues[stale_issues['closed_at'].isnull()]

# %%
stale_issues[['user', 'author_association', 'comments', 'html_url']]\
    .sort_values(['comments']).style.applymap(highlight_rows).format({'html_url': make_clickable}).hide_index()
# Out:
# <style  type="text/css" >
#     #T_86172c62_3400_11e9_b60e_54ee75e0f62drow0_col1 {
#             background-color:  #f7b7b7;
#         }    #T_86172c62_3400_11e9_b60e_54ee75e0f62drow0_col2 {
#             background-color:  #f7b7b7;
#         }    #T_86172c62_3400_11e9_b60e_54ee75e0f62drow1_col2 {
#             background-color:  #f7b7b7;
#         }    #T_86172c62_3400_11e9_b60e_54ee75e0f62drow2_col1 {
#             background-color:  #f7b7b7;
#         }    #T_86172c62_3400_11e9_b60e_54ee75e0f62drow2_col2 {
#             background-color:  #f7b7b7;
#         }    #T_86172c62_3400_11e9_b60e_54ee75e0f62drow3_col2 {
#             background-color:  #f7b7b7;
#         }    #T_86172c62_3400_11e9_b60e_54ee75e0f62drow4_col2 {
#             background-color:  #f7b7b7;
#         }    #T_86172c62_3400_11e9_b60e_54ee75e0f62drow5_col1 {
#             background-color:  #f7b7b7;
#         }    #T_86172c62_3400_11e9_b60e_54ee75e0f62drow5_col2 {
#             background-color:  #f7b7b7;
#         }    #T_86172c62_3400_11e9_b60e_54ee75e0f62drow6_col1 {
#             background-color:  #f7b7b7;
#         }    #T_86172c62_3400_11e9_b60e_54ee75e0f62drow6_col2 {
#             background-color:  #f7b7b7;
#         }    #T_86172c62_3400_11e9_b60e_54ee75e0f62drow7_col1 {
#             background-color:  #f7b7b7;
#         }    #T_86172c62_3400_11e9_b60e_54ee75e0f62drow7_col2 {
#             background-color:  #f7b7b7;
#         }    #T_86172c62_3400_11e9_b60e_54ee75e0f62drow8_col2 {
#             background-color:  #f7b7b7;
#         }    #T_86172c62_3400_11e9_b60e_54ee75e0f62drow9_col2 {
#             background-color:  #f7b7b7;
#         }    #T_86172c62_3400_11e9_b60e_54ee75e0f62drow10_col2 {
#             background-color:  #f7b7b7;
#         }    #T_86172c62_3400_11e9_b60e_54ee75e0f62drow11_col1 {
#             background-color:  #f7b7b7;
#         }    #T_86172c62_3400_11e9_b60e_54ee75e0f62drow11_col2 {
#             background-color:  #f7b7b7;
#         }    #T_86172c62_3400_11e9_b60e_54ee75e0f62drow12_col1 {
#             background-color:  #f7b7b7;
#         }    #T_86172c62_3400_11e9_b60e_54ee75e0f62drow12_col2 {
#             background-color:  #f7b7b7;
#         }    #T_86172c62_3400_11e9_b60e_54ee75e0f62drow13_col1 {
#             background-color:  #f7b7b7;
#         }    #T_86172c62_3400_11e9_b60e_54ee75e0f62drow13_col2 {
#             background-color:  #f7b7b7;
#         }    #T_86172c62_3400_11e9_b60e_54ee75e0f62drow14_col2 {
#             background-color:  #f7b7b7;
#         }    #T_86172c62_3400_11e9_b60e_54ee75e0f62drow15_col2 {
#             background-color:  #f7b7b7;
#         }    #T_86172c62_3400_11e9_b60e_54ee75e0f62drow16_col1 {
#             background-color:  #f7b7b7;
#         }    #T_86172c62_3400_11e9_b60e_54ee75e0f62drow16_col2 {
#             background-color:  #f7b7b7;
#         }    #T_86172c62_3400_11e9_b60e_54ee75e0f62drow17_col1 {
#             background-color:  #f7b7b7;
#         }    #T_86172c62_3400_11e9_b60e_54ee75e0f62drow17_col2 {
#             background-color:  #f7b7b7;
#         }    #T_86172c62_3400_11e9_b60e_54ee75e0f62drow18_col2 {
#             background-color:  #f7b7b7;
#         }    #T_86172c62_3400_11e9_b60e_54ee75e0f62drow19_col2 {
#             background-color:  #f7b7b7;
#         }    #T_86172c62_3400_11e9_b60e_54ee75e0f62drow20_col2 {
#             background-color:  #f7b7b7;
#         }    #T_86172c62_3400_11e9_b60e_54ee75e0f62drow21_col1 {
#             background-color:  #f7b7b7;
#         }    #T_86172c62_3400_11e9_b60e_54ee75e0f62drow21_col2 {
#             background-color:  #f7b7b7;
#         }    #T_86172c62_3400_11e9_b60e_54ee75e0f62drow22_col1 {
#             background-color:  red;
#         }    #T_86172c62_3400_11e9_b60e_54ee75e0f62drow22_col2 {
#             background-color:  #f7b7b7;
#         }    #T_86172c62_3400_11e9_b60e_54ee75e0f62drow23_col1 {
#             background-color:  #f7b7b7;
#         }    #T_86172c62_3400_11e9_b60e_54ee75e0f62drow23_col2 {
#             background-color:  #f7b7b7;
#         }    #T_86172c62_3400_11e9_b60e_54ee75e0f62drow24_col2 {
#             background-color:  #f7b7b7;
#         }    #T_86172c62_3400_11e9_b60e_54ee75e0f62drow25_col1 {
#             background-color:  #f7b7b7;
#         }    #T_86172c62_3400_11e9_b60e_54ee75e0f62drow25_col2 {
#             background-color:  #f7b7b7;
#         }    #T_86172c62_3400_11e9_b60e_54ee75e0f62drow26_col2 {
#             background-color:  #f7b7b7;
#         }    #T_86172c62_3400_11e9_b60e_54ee75e0f62drow27_col2 {
#             background-color:  #f7b7b7;
#         }    #T_86172c62_3400_11e9_b60e_54ee75e0f62drow28_col2 {
#             background-color:  #f7b7b7;
#         }    #T_86172c62_3400_11e9_b60e_54ee75e0f62drow29_col2 {
#             background-color:  #f7b7b7;
#         }    #T_86172c62_3400_11e9_b60e_54ee75e0f62drow31_col1 {
#             background-color:  #f7b7b7;
#         }    #T_86172c62_3400_11e9_b60e_54ee75e0f62drow32_col1 {
#             background-color:  #f7b7b7;
#         }    #T_86172c62_3400_11e9_b60e_54ee75e0f62drow33_col1 {
#             background-color:  #f7b7b7;
#         }    #T_86172c62_3400_11e9_b60e_54ee75e0f62drow35_col1 {
#             background-color:  #f7b7b7;
#         }    #T_86172c62_3400_11e9_b60e_54ee75e0f62drow36_col1 {
#             background-color:  #f7b7b7;
#         }    #T_86172c62_3400_11e9_b60e_54ee75e0f62drow37_col1 {
#             background-color:  #f7b7b7;
#         }    #T_86172c62_3400_11e9_b60e_54ee75e0f62drow39_col1 {
#             background-color:  #f7b7b7;
#         }    #T_86172c62_3400_11e9_b60e_54ee75e0f62drow41_col1 {
#             background-color:  #f7b7b7;
#         }    #T_86172c62_3400_11e9_b60e_54ee75e0f62drow43_col1 {
#             background-color:  #f7b7b7;
#         }    #T_86172c62_3400_11e9_b60e_54ee75e0f62drow44_col1 {
#             background-color:  #f7b7b7;
#         }    #T_86172c62_3400_11e9_b60e_54ee75e0f62drow45_col1 {
#             background-color:  #f7b7b7;
#         }    #T_86172c62_3400_11e9_b60e_54ee75e0f62drow48_col1 {
#             background-color:  #f7b7b7;
#         }    #T_86172c62_3400_11e9_b60e_54ee75e0f62drow49_col1 {
#             background-color:  #f7b7b7;
#         }    #T_86172c62_3400_11e9_b60e_54ee75e0f62drow50_col1 {
#             background-color:  #f7b7b7;
#         }    #T_86172c62_3400_11e9_b60e_54ee75e0f62drow51_col1 {
#             background-color:  #f7b7b7;
#         }    #T_86172c62_3400_11e9_b60e_54ee75e0f62drow54_col1 {
#             background-color:  #f7b7b7;
#         }    #T_86172c62_3400_11e9_b60e_54ee75e0f62drow55_col1 {
#             background-color:  #f7b7b7;
#         }    #T_86172c62_3400_11e9_b60e_54ee75e0f62drow57_col1 {
#             background-color:  #f7b7b7;
#         }    #T_86172c62_3400_11e9_b60e_54ee75e0f62drow58_col1 {
#             background-color:  #f7b7b7;
#         }    #T_86172c62_3400_11e9_b60e_54ee75e0f62drow60_col1 {
#             background-color:  #f7b7b7;
#         }    #T_86172c62_3400_11e9_b60e_54ee75e0f62drow62_col1 {
#             background-color:  #f7b7b7;
#         }    #T_86172c62_3400_11e9_b60e_54ee75e0f62drow64_col1 {
#             background-color:  #f7b7b7;
#         }    #T_86172c62_3400_11e9_b60e_54ee75e0f62drow65_col1 {
#             background-color:  #f7b7b7;
#         }    #T_86172c62_3400_11e9_b60e_54ee75e0f62drow66_col1 {
#             background-color:  #f7b7b7;
#         }    #T_86172c62_3400_11e9_b60e_54ee75e0f62drow67_col1 {
#             background-color:  #f7b7b7;
#         }    #T_86172c62_3400_11e9_b60e_54ee75e0f62drow69_col1 {
#             background-color:  #f7b7b7;
#         }    #T_86172c62_3400_11e9_b60e_54ee75e0f62drow70_col1 {
#             background-color:  #f7b7b7;
#         }    #T_86172c62_3400_11e9_b60e_54ee75e0f62drow73_col1 {
#             background-color:  #f7b7b7;
#         }    #T_86172c62_3400_11e9_b60e_54ee75e0f62drow74_col1 {
#             background-color:  #f7b7b7;
#         }    #T_86172c62_3400_11e9_b60e_54ee75e0f62drow75_col1 {
#             background-color:  #f7b7b7;
#         }    #T_86172c62_3400_11e9_b60e_54ee75e0f62drow79_col1 {
#             background-color:  #f7b7b7;
#         }    #T_86172c62_3400_11e9_b60e_54ee75e0f62drow80_col1 {
#             background-color:  #f7b7b7;
#         }    #T_86172c
