# %%
import pandas as pd
from datetime import timedelta
from IPython.display import HTML, display

# %%
date = pd.datetime.today() - timedelta(days=30)
org = 'jupyterhub'
repo = 'zero-to-jupyterhub-k8s'

# %%
# Parameters
org = "jupyterhub"
repo = "binderhub"
date = "2019-01-19"

# %%
# Definition of a stale issue/PR (how many days since last updated)
date = pd.to_datetime(date)
stale_days = 30
date_stale = date - timedelta(days=stale_days)

# %% [markdown]
# # Opened and Closed Issues and PRs
#
# This report shows opened and closed issues / PRs over the last 30 days, with a
# particular focus on items that haven't had a lot of discussion, or that have
# been opened by people who aren't team-members. The goal of this page is to make
# it easier to spot places where some input would be appreciated!

# %% [markdown]
# # Imports

# %%
import pandas as pd
from subprocess import run, PIPE
from watchtower import issues_
from glob import glob
import os.path as op
import shutil as sh
import sys
sys.path.append('../../scripts/')

# %% [markdown]
# ## styling functions

# %%
def highlight_rows(val):
    """Highlights cells pertaining to non-members and w/ no comments"""
    disp = ''
    if val == 0 or val == "NONE":
        disp += 'background-color: #f7b7b7'
    elif val == "FIRST_TIME_CONTRIBUTOR":
        disp += 'background-color: red'
    return disp

def make_clickable(val):
    # target _blank to open new window
    return '<a target="_blank" href="{}">{}</a>'.format(val, val)

def print_html(msg):
    display(HTML('<h2 style="padding-left: 1em;">{}</h2>'.format(msg)))
    
pd.options.display.max_colwidth = 200

# %% [markdown]
# ## Load data

# %%
# Issues
issues = issues_.load_issues(org, repo)
issues['user'] = issues['user'].map(lambda a: a['login'])

# %% [markdown]
# # New activity

# %% [markdown]
# ## Opened issues
#
# without responses in red

# %%
opened = issues.query('created_at > @date')
opened_issues = opened[opened['pull_request'].isna()]
opened_issues['closed'] = ~pd.isnull(opened_issues['closed_at'])
# Out:
# /home/choldgraf/anaconda/envs/dev/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
print_html('Opened issues: {}'.format(len(opened_issues)))
# Out:
# <h2 style="padding-left: 1em;">Opened issues: 7</h2>

# %%
opened_issues[['user', 'author_association', 'comments', 'closed', 'html_url']]\
    .sort_values(['closed', 'comments']).style.applymap(highlight_rows).format({'html_url': make_clickable}).hide_index()
# Out:
# <style  type="text/css" >
#     #T_8e207396_3400_11e9_a32f_54ee75e0f62drow0_col3 {
#             background-color:  #f7b7b7;
#         }    #T_8e207396_3400_11e9_a32f_54ee75e0f62drow1_col3 {
#             background-color:  #f7b7b7;
#         }    #T_8e207396_3400_11e9_a32f_54ee75e0f62drow2_col1 {
#             background-color:  #f7b7b7;
#         }    #T_8e207396_3400_11e9_a32f_54ee75e0f62drow2_col3 {
#             background-color:  #f7b7b7;
#         }    #T_8e207396_3400_11e9_a32f_54ee75e0f62drow3_col3 {
#             background-color:  #f7b7b7;
#         }    #T_8e207396_3400_11e9_a32f_54ee75e0f62drow4_col2 {
#             background-color:  #f7b7b7;
#         }    #T_8e207396_3400_11e9_a32f_54ee75e0f62drow5_col1 {
#             background-color:  #f7b7b7;
#         }    #T_8e207396_3400_11e9_a32f_54ee75e0f62drow6_col1 {
#             background-color:  #f7b7b7;
#         }</style><table id="T_8e207396_3400_11e9_a32f_54ee75e0f62d" ><thead>    <tr>        <th class="col_heading level0 col0" >user</th>        <th class="col_heading level0 col1" >author_association</th>        <th class="col_heading level0 col2" >comments</th>        <th class="col_heading level0 col3" >closed</th>        <th class="col_heading level0 col4" >html_url</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_8e207396_3400_11e9_a32f_54ee75e0f62drow0_col0" class="data row0 col0" >betatim</td>
#                         <td id="T_8e207396_3400_11e9_a32f_54ee75e0f62drow0_col1" class="data row0 col1" >MEMBER</td>
#                         <td id="T_8e207396_3400_11e9_a32f_54ee75e0f62drow0_col2" class="data row0 col2" >2</td>
#                         <td id="T_8e207396_3400_11e9_a32f_54ee75e0f62drow0_col3" class="data row0 col3" >False</td>
#                         <td id="T_8e207396_3400_11e9_a32f_54ee75e0f62drow0_col4" class="data row0 col4" ><a target="_blank" href="https://github.com/jupyterhub/binderhub/issues/786">https://github.com/jupyterhub/binderhub/issues/786</a></td>
#             </tr>
#             <tr>
#                                 <td id="T_8e207396_3400_11e9_a32f_54ee75e0f62drow1_col0" class="data row1 col0" >captainsafia</td>
#                         <td id="T_8e207396_3400_11e9_a32f_54ee75e0f62drow1_col1" class="data row1 col1" >MEMBER</td>
#                         <td id="T_8e207396_3400_11e9_a32f_54ee75e0f62drow1_col2" class="data row1 col2" >2</td>
#                         <td id="T_8e207396_3400_11e9_a32f_54ee75e0f62drow1_col3" class="data row1 col3" >False</td>
#                         <td id="T_8e207396_3400_11e9_a32f_54ee75e0f62drow1_col4" class="data row1 col4" ><a target="_blank" href="https://github.com/jupyterhub/binderhub/issues/777">https://github.com/jupyterhub/binderhub/issues/777</a></td>
#             </tr>
#             <tr>
#                                 <td id="T_8e207396_3400_11e9_a32f_54ee75e0f62drow2_col0" class="data row2 col0" >andrewjohnlowe</td>
#                         <td id="T_8e207396_3400_11e9_a32f_54ee75e0f62drow2_col1" class="data row2 col1" >NONE</td>
#                         <td id="T_8e207396_3400_11e9_a32f_54ee75e0f62drow2_col2" class="data row2 col2" >9</td>
#                         <td id="T_8e207396_3400_11e9_a32f_54ee75e0f62drow2_col3" class="data row2 col3" >False</td>
#                         <td id="T_8e207396_3400_11e9_a32f_54ee75e0f62drow2_col4" class="data row2 col4" ><a target="_blank" href="https://github.com/jupyterhub/binderhub/issues/785">https://github.com/jupyterhub/binderhub/issues/785</a></td>
#             </tr>
#             <tr>
#                                 <td id="T_8e207396_3400_11e9_a32f_54ee75e0f62drow3_col0" class="data row3 col0" >yuvipanda</td>
#                         <td id="T_8e207396_3400_11e9_a32f_54ee75e0f62drow3_col1" class="data row3 col1" >MEMBER</td>
#                         <td id="T_8e207396_3400_11e9_a32f_54ee75e0f62drow3_col2" class="data row3 col2" >18</td>
#                         <td id="T_8e207396_3400_11e9_a32f_54ee75e0f62drow3_col3" class="data row3 col3" >False</td>
#                         <td id="T_8e207396_3400_11e9_a32f_54ee75e0f62drow3_col4" class="data row3 col4" ><a target="_blank" href="https://github.com/jupyterhub/binderhub/issues/774">https://github.com/jupyterhub/binderhub/issues/774</a></td>
#             </tr>
#             <tr>
#                                 <td id="T_8e207396_3400_11e9_a32f_54ee75e0f62drow4_col0" class="data row4 col0" >yuvipanda</td>
#                         <td id="T_8e207396_3400_11e9_a32f_54ee75e0f62drow4_col1" class="data row4 col1" >MEMBER</td>
#                         <td id="T_8e207396_3400_11e9_a32f_54ee75e0f62drow4_col2" class="data row4 col2" >0</td>
#                         <td id="T_8e207396_3400_11e9_a32f_54ee75e0f62drow4_col3" class="data row4 col3" >True</td>
#                         <td id="T_8e207396_3400_11e9_a32f_54ee75e0f62drow4_col4" class="data row4 col4" ><a target="_blank" href="https://github.com/jupyterhub/binderhub/issues/772">https://github.com/jupyterhub/binderhub/issues/772</a></td>
#             </tr>
#             <tr>
#                                 <td id="T_8e207396_3400_11e9_a32f_54ee75e0f62drow5_col0" class="data row5 col0" >davidlowryduda</td>
#                         <td id="T_8e207396_3400_11e9_a32f_54ee75e0f62drow5_col1" class="data row5 col1" >NONE</td>
#                         <td id="T_8e207396_3400_11e9_a32f_54ee75e0f62drow5_col2" class="data row5 col2" >1</td>
#                         <td id="T_8e207396_3400_11e9_a32f_54ee75e0f62drow5_col3" class="data row5 col3" >True</td>
#                         <td id="T_8e207396_3400_11e9_a32f_54ee75e0f62drow5_col4" class="data row5 col4" ><a target="_blank" href="https://github.com/jupyterhub/binderhub/issues/788">https://github.com/jupyterhub/binderhub/issues/788</a></td>
#             </tr>
#             <tr>
#                                 <td id="T_8e207396_3400_11e9_a32f_54ee75e0f62drow6_col0" class="data row6 col0" >mbobra</td>
#                         <td id="T_8e207396_3400_11e9_a32f_54ee75e0f62drow6_col1" class="data row6 col1" >NONE</td>
#                         <td id="T_8e207396_3400_11e9_a32f_54ee75e0f62drow6_col2" class="data row6 col2" >2</td>
#                         <td id="T_8e207396_3400_11e9_a32f_54ee75e0f62drow6_col3" class="data row6 col3" >True</td>
#                         <td id="T_8e207396_3400_11e9_a32f_54ee75e0f62drow6_col4" class="data row6 col4" ><a target="_blank" href="https://github.com/jupyterhub/binderhub/issues/789">https://github.com/jupyterhub/binderhub/issues/789</a></td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## Closed issues

# %%
closed = issues.query('closed_at > @date')
closed_issues = closed[closed['pull_request'].isna()]

# %%
closed_issues[['user', 'author_association', 'comments', 'html_url']]\
    .sort_values(['comments']).style.applymap(highlight_rows).format({'html_url': make_clickable}).hide_index()
# Out:
# <style  type="text/css" >
#     #T_8e508fea_3400_11e9_a32f_54ee75e0f62drow0_col2 {
#             background-color:  #f7b7b7;
#         }    #T_8e508fea_3400_11e9_a32f_54ee75e0f62drow1_col1 {
#             background-color:  #f7b7b7;
#         }    #T_8e508fea_3400_11e9_a32f_54ee75e0f62drow1_col2 {
#             background-color:  #f7b7b7;
#         }    #T_8e508fea_3400_11e9_a32f_54ee75e0f62drow3_col1 {
#             background-color:  #f7b7b7;
#         }    #T_8e508fea_3400_11e9_a32f_54ee75e0f62drow4_col1 {
#             background-color:  #f7b7b7;
#         }    #T_8e508fea_3400_11e9_a32f_54ee75e0f62drow5_col1 {
#             background-color:  #f7b7b7;
#         }</style><table id="T_8e508fea_3400_11e9_a32f_54ee75e0f62d" ><thead>    <tr>        <th class="col_heading level0 col0" >user</th>        <th class="col_heading level0 col1" >author_association</th>        <th class="col_heading level0 col2" >comments</th>        <th class="col_heading level0 col3" >html_url</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_8e508fea_3400_11e9_a32f_54ee75e0f62drow0_col0" class="data row0 col0" >yuvipanda</td>
#                         <td id="T_8e508fea_3400_11e9_a32f_54ee75e0f62drow0_col1" class="data row0 col1" >MEMBER</td>
#                         <td id="T_8e508fea_3400_11e9_a32f_54ee75e0f62drow0_col2" class="data row0 col2" >0</td>
#                         <td id="T_8e508fea_3400_11e9_a32f_54ee75e0f62drow0_col3" class="data row0 col3" ><a target="_blank" href="https://github.com/jupyterhub/binderhub/issues/772">https://github.com/jupyterhub/binderhub/issues/772</a></td>
#             </tr>
#             <tr>
#                                 <td id="T_8e508fea_3400_11e9_a32f_54ee75e0f62drow1_col0" class="data row1 col0" >psychemedia</td>
#                         <td id="T_8e508fea_3400_11e9_a32f_54ee75e0f62drow1_col1" class="data row1 col1" >NONE</td>
#                         <td id="T_8e508fea_3400_11e9_a32f_54ee75e0f62drow1_col2" class="data row1 col2" >0</td>
#                         <td id="T_8e508fea_3400_11e9_a32f_54ee75e0f62drow1_col3" class="data row1 col3" ><a target="_blank" href="https://github.com/jupyterhub/binderhub/issues/747">https://github.com/jupyterhub/binderhub/issues/747</a></td>
#             </tr>
#             <tr>
#                                 <td id="T_8e508fea_3400_11e9_a32f_54ee75e0f62drow2_col0" class="data row2 col0" >betatim</td>
#                         <td id="T_8e508fea_3400_11e9_a32f_54ee75e0f62drow2_col1" class="data row2 col1" >MEMBER</td>
#                         <td id="T_8e508fea_3400_11e9_a32f_54ee75e0f62drow2_col2" class="data row2 col2" >1</td>
#                         <td id="T_8e508fea_3400_11e9_a32f_54ee75e0f62drow2_col3" class="data row2 col3" ><a target="_blank" href="https://github.com/jupyterhub/binderhub/issues/608">https://github.com/jupyterhub/binderhub/issues/608</a></td>
#             </tr>
#             <tr>
#                                 <td id="T_8e508fea_3400_11e9_a32f_54ee75e0f62drow3_col0" class="data row3 col0" >davidlowryduda</td>
#                         <td id="T_8e508fea_3400_11e9_a32f_54ee75e0f62drow3_col1" class="data row3 col1" >NONE</td>
#                         <td id="T_8e508fea_3400_11e9_a32f_54ee75e0f62drow3_col2" class="data row3 col2" >1</td>
#                         <td id="T_8e508fea_3400_11e9_a32f_54ee75e0f62drow3_col3" class="data row3 col3" ><a target="_blank" href="https://github.com/jupyterhub/binderhub/issues/788">https://github.com/jupyterhub/binderhub/issues/788</a></td>
#             </tr>
#             <tr>
#                                 <td id="T_8e508fea_3400_11e9_a32f_54ee75e0f62drow4_col0" class="data row4 col0" >mbobra</td>
#                         <td id="T_8e508fea_3400_11e9_a32f_54ee75e0f62drow4_col1" class="data row4 col1" >NONE</td>
#                         <td id="T_8e508fea_3400_11e9_a32f_54ee75e0f62drow4_col2" class="data row4 col2" >2</td>
#                         <td id="T_8e508fea_3400_11e9_a32f_54ee75e0f62drow4_col3" class="data row4 col3" ><a target="_blank" href="https://github.com/jupyterhub/binderhub/issues/789">https://github.com/jupyterhub/binderhub/issues/789</a></td>
#             </tr>
#             <tr>
#                                 <td id="T_8e508fea_3400_11e9_a32f_54ee75e0f62drow5_col0" class="data row5 col0" >fmaussion</td>
#                         <td id="T_8e508fea_3400_11e9_a32f_54ee75e0f62drow5_col1" class="data row5 col1" >NONE</td>
#                         <td id="T_8e508fea_3400_11e9_a32f_54ee75e0f62drow5_col2" class="data row5 col2" >3</td>
#                         <td id="T_8e508fea_3400_11e9_a32f_54ee75e0f62drow5_col3" class="data row5 col3" ><a target="_blank" href="https://github.com/jupyterhub/binderhub/issues/764">https://github.com/jupyterhub/binderhub/issues/764</a></td>
#             </tr>
#             <tr>
#                                 <td id="T_8e508fea_3400_11e9_a32f_54ee75e0f62drow6_col0" class="data row6 col0" >yuvipanda</td>
#                         <td id="T_8e508fea_3400_11e9_a32f_54ee75e0f62drow6_col1" class="data row6 col1" >MEMBER</td>
#                         <td id="T_8e508fea_3400_11e9_a32f_54ee75e0f62drow6_col2" class="data row6 col2" >3</td>
#                         <td id="T_8e508fea_3400_11e9_a32f_54ee75e0f62drow6_col3" class="data row6 col3" ><a target="_blank" href="https://github.com/jupyterhub/binderhub/issues/356">https://github.com/jupyterhub/binderhub/issues/356</a></td>
#             </tr>
#     </tbody></table>

# %%
print_html('Closed issues: {}'.format(len(closed_issues)))
# Out:
# <h2 style="padding-left: 1em;">Closed issues: 7</h2>

# %% [markdown]
# ## Opened PRs
#
# without responses in red

# %%
opened_prs = opened[~opened['pull_request'].isna()]
opened_prs['closed'] = ~pd.isnull(opened_prs['closed_at'])

closed_prs = closed[~closed['pull_request'].isna()]
# Out:
# /home/choldgraf/anaconda/envs/dev/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
print_html('Opened PRs: {}'.format(len(opened_prs)))
# Out:
# <h2 style="padding-left: 1em;">Opened PRs: 14</h2>

# %%
opened_prs[['user', 'author_association', 'comments', 'closed', 'html_url']]\
    .sort_values(['closed', 'comments']).style.applymap(highlight_rows).format({'html_url': make_clickable}).hide_index()
# Out:
# <style  type="text/css" >
#     #T_8e904edc_3400_11e9_a32f_54ee75e0f62drow0_col2 {
#             background-color:  #f7b7b7;
#         }    #T_8e904edc_3400_11e9_a32f_54ee75e0f62drow0_col3 {
#             background-color:  #f7b7b7;
#         }    #T_8e904edc_3400_11e9_a32f_54ee75e0f62drow1_col3 {
#             background-color:  #f7b7b7;
#         }    #T_8e904edc_3400_11e9_a32f_54ee75e0f62drow2_col2 {
#             background-color:  #f7b7b7;
#         }    #T_8e904edc_3400_11e9_a32f_54ee75e0f62drow3_col2 {
#             background-color:  #f7b7b7;
#         }    #T_8e904edc_3400_11e9_a32f_54ee75e0f62drow4_col2 {
#             background-color:  #f7b7b7;
#         }</style><table id="T_8e904edc_3400_11e9_a32f_54ee75e0f62d" ><thead>    <tr>        <th class="col_heading level0 col0" >user</th>        <th class="col_heading level0 col1" >author_association</th>        <th class="col_heading level0 col2" >comments</th>        <th class="col_heading level0 col3" >closed</th>        <th class="col_heading level0 col4" >html_url</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_8e904edc_3400_11e9_a32f_54ee75e0f62drow0_col0" class="data row0 col0" >minrk</td>
#                         <td id="T_8e904edc_3400_11e9_a32f_54ee75e0f62drow0_col1" class="data row0 col1" >MEMBER</td>
#                         <td id="T_8e904edc_3400_11e9_a32f_54ee75e0f62drow0_col2" class="data row0 col2" >0</td>
#                         <td id="T_8e904edc_3400_11e9_a32f_54ee75e0f62drow0_col3" class="data row0 col3" >False</td>
#                         <td id="T_8e904edc_3400_11e9_a32f_54ee75e0f62drow0_col4" class="data row0 col4" ><a target="_blank" href="https://github.com/jupyterhub/binderhub/pull/784">https://github.com/jupyterhub/binderhub/pull/784</a></td>
#             </tr>
#             <tr>
#                                 <td id="T_8e904edc_3400_11e9_a32f_54ee75e0f62drow1_col0" class="data row1 col0" >betatim</td>
#                         <td id="T_8e904edc_3400_11e9_a32f_54ee75e0f62drow1_col1" class="data row1 col1" >MEMBER</td>
#                         <td id="T_8e904edc_3400_11e9_a32f_54ee75e0f62drow1_col2" class="data row1 col2" >2</td>
#                         <td id="T_8e904edc_3400_11e9_a32f_54ee75e0f62drow1_col3" class="data row1 col3" >False</td>
#                         <td id="T_8e904edc_3400_11e9_a32f_54ee75e0f62drow1_col4" class="data row1 col4" ><a target="_blank" href="https://github.com/jupyterhub/binderhub/pull/787">https://github.com/jupyterhub/binderhub/pull/787</a></td>
#             </tr>
#             <tr>
#                                 <td id="T_8e904edc_3400_11e9_a32f_54ee75e0f62drow2_col0" class="data row2 col0" >choldgraf</td>
#                         <td id="T_8e904edc_3400_11e9_a32f_54ee75e0f62drow2_col1" class="data row2 col1" >MEMBER</td>
#                         <td id="T_8e904edc_3400_11e9_a32f_54ee75e0f62drow2_col2" class="data row2 col2" >0</td>
#                         <td id="T_8e904edc_3400_11e9_a32f_54ee75e0f62drow2_col3" class="data row2 col3" >True</td>
#                         <td id="T_8e904edc_3400_11e9_a32f_54ee75e0f62drow2_col4" class="data row2 col4" ><a target="_blank" href="https://github.com/jupyterhub/binderhub/pull/782">https://github.com/jupyterhub/binderhub/pull/782</a></td>
#             </tr>
#             <tr>
#                                 <td id="T_8e904edc_3400_11e9_a32f_54ee75e0f62drow3_col0" class="data row3 col0" >consideRatio</td>
#                         <td id="T_8e904edc_3400_11e9_a32f_54ee75e0f62drow3_col1" class="data row3 col1" >MEMBER</td>
#                         <td id="T_8e904edc_3400_11e9_a32f_54ee75e0f62drow3_col2" class="data row3 col2" >0</td>
#                         <td id="T_8e904edc_3400_11e9_a32f_54ee75e0f62drow3_col3" class="data row3 col3" >True</td>
#                         <td id="T_8e904edc_3400_11e9_a32f_54ee75e0f62drow3_col4" class="data row3 col4" ><a target="_blank" href="https://github.com/jupyterhub/binderhub/pull/780">https://github.com/jupyterhub/binderhub/pull/780</a></td>
#             </tr>
#             <tr>
#                                 <td id="T_8e904edc_3400_11e9_a32f_54ee75e0f62drow4_col0" class="data row4 col0" >captainsafia</td>
#                         <td id="T_8e904edc_3400_11e9_a32f_54ee75e0f62drow4_col1" class="data row4 col1" >MEMBER</td>
#                         <td id="T_8e904edc_3400_11e9_a32f_54ee75e0f62drow4_col2" class="data row4 col2" >0</td>
#                         <td id="T_8e904edc_3400_11e9_a32f_54ee75e0f62drow4_col3" class="data row4 col3" >True</td>
#                         <td id="T_8e904edc_3400_11e9_a32f_54ee75e0f62drow4_col4" class="data row4 col4" ><a target="_blank" href="https://github.com/jupyterhub/binderhub/pull/778">https://github.com/jupyterhub/binderhub/pull/778</a></td>
#             </tr>
#             <tr>
#                                 <td id="T_8e904edc_3400_11e9_a32f_54ee75e0f62drow5_col0" class="data row5 col0" >choldgraf</td>
#                         <td id="T_8e904edc_3400_11e9_a32f_54ee75e0f62drow5_col1" class="data row5 col1" >MEMBER</td>
#                         <td id="T_8e904edc_3400_11e9_a32f_54ee75e0f62drow5_col2" class="data row5 col2" >1</td>
#                         <td id="T_8e904edc_3400_11e9_a32f_54ee75e0f62drow5_col3" class="data row5 col3" >True</td>
#                         <td id="T_8e904edc_3400_11e9_a32f_54ee75e0f62drow5_col4" class="data row5 col4" ><a target="_blank" href="https://github.com/jupyterhub/binderhub/pull/792">https://github.com/jupyterhub/binderhub/pull/792</a></td>
#             </tr>
#             <tr>
#                                 <td id="T_8e904edc_3400_11e9_a32f_54ee75e0f62drow6_col0" class="data row6 col0" >choldgraf</td>
#                         <td id="T_8e904edc_3400_11e9_a32f_54ee75e0f62drow6_col1" class="data row6 col1" >MEMBER</td>
#                         <td id="T_8e904edc_3400_11e9_a32f_54ee75e0f62drow6_col2" class="data row6 col2" >1</td>
#                         <td id="T_8e904edc_3400_11e9_a32f_54ee75e0f62drow6_col3" class="data row6 col3" >True</td>
#                         <td id="T_8e904edc_3400_11e9_a32f_54ee75e0f62drow6_col4" class="data row6 col4" ><a target="_blank" href="https://github.com/jupyterhub/binderhub/pull/791">https://github.com/jupyterhub/binderhub/pull/791</a></td>
#             </tr>
#             <tr>
#                                 <td id="T_8e904edc_3400_11e9_a32f_54ee75e0f62drow7_col0" class="data row7 col0" >betatim</td>
#                         <td id="T_8e904edc_3400_11e9_a32f_54ee75e0f62drow7_col1" class="data row7 col1" >MEMBER</td>
#                         <td id="T_8e904edc_3400_11e9_a32f_54ee75e0f62drow7_col2" class="data row7 col2" >1</td>
#                         <td id="T_8e904edc_3400_11e9_a32f_54ee75e0f62drow7_col3" class="data row7 col3" >True</td>
#                         <td id="T_8e904edc_3400_11e9_a32f_54ee75e0f62drow7_col4" class="data row7 col4" ><a target="_blank" href="https://github.com/jupyterhub/binderhub/pull/773">https://github.com/jupyterhub/binderhub/pull/773</a></td>
#             </tr>
#             <tr>
#                                 <td id="T_8e904edc_3400_11e9_a32f_54ee75e0f62drow8_col0" class="data row8 col0" >minrk</td>
#                         <td id="T_8e904edc_3400_11e9_a32f_54ee75e0f62drow8_col1" class="data row8 col1" >MEMBER</td>
#                         <td id="T_8e904edc_3400_11e9_a32f_54ee75e0f62drow8_col2" class="data row8 col2" >1</td>
#                         <td id="T_8e904edc_3400_11e9_a32f_54ee75e0f62drow8_col3" class="data row8 col3" >True</td>
#                         <td id="T_8e904edc_3400_11e9_a32f_54ee75e0f62drow8_col4" class="data row8 col4" ><a target="_blank" href="https://github.com/jupyterhub/binderhub/pull/790">https://github.com/jupyterhub/binderhub/pull/790</a></td>
#             </tr>
#             <tr>
#                                 <td id="T_8e904edc_3400_11e9_a32f_54ee75e0f62drow9_col0" class="data row9 col0" >captainsafia</td>
#                         <td id="T_8e904edc_3400_11e9_a32f_54ee75e0f62drow9_col1" class="data row9 col1"

# %%
print_html('Closed PRs: {}'.format(len(closed_prs)))
# Out:
# <h2 style="padding-left: 1em;">Closed PRs: 14</h2>

# %%
closed_prs[['user', 'author_association', 'comments', 'html_url']]\
    .sort_values(['comments']).style.applymap(highlight_rows).format({'html_url': make_clickable}).hide_index()
# Out:
# <style  type="text/css" >
#     #T_8eafa80e_3400_11e9_a32f_54ee75e0f62drow0_col2 {
#             background-color:  #f7b7b7;
#         }    #T_8eafa80e_3400_11e9_a32f_54ee75e0f62drow1_col2 {
#             background-color:  #f7b7b7;
#         }    #T_8eafa80e_3400_11e9_a32f_54ee75e0f62drow2_col2 {
#             background-color:  #f7b7b7;
#         }</style><table id="T_8eafa80e_3400_11e9_a32f_54ee75e0f62d" ><thead>    <tr>        <th class="col_heading level0 col0" >user</th>        <th class="col_heading level0 col1" >author_association</th>        <th class="col_heading level0 col2" >comments</th>        <th class="col_heading level0 col3" >html_url</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_8eafa80e_3400_11e9_a32f_54ee75e0f62drow0_col0" class="data row0 col0" >choldgraf</td>
#                         <td id="T_8eafa80e_3400_11e9_a32f_54ee75e0f62drow0_col1" class="data row0 col1" >MEMBER</td>
#                         <td id="T_8eafa80e_3400_11e9_a32f_54ee75e0f62drow0_col2" class="data row0 col2" >0</td>
#                         <td id="T_8eafa80e_3400_11e9_a32f_54ee75e0f62drow0_col3" class="data row0 col3" ><a target="_blank" href="https://github.com/jupyterhub/binderhub/pull/782">https://github.com/jupyterhub/binderhub/pull/782</a></td>
#             </tr>
#             <tr>
#                                 <td id="T_8eafa80e_3400_11e9_a32f_54ee75e0f62drow1_col0" class="data row1 col0" >consideRatio</td>
#                         <td id="T_8eafa80e_3400_11e9_a32f_54ee75e0f62drow1_col1" class="data row1 col1" >MEMBER</td>
#                         <td id="T_8eafa80e_3400_11e9_a32f_54ee75e0f62drow1_col2" class="data row1 col2" >0</td>
#                         <td id="T_8eafa80e_3400_11e9_a32f_54ee75e0f62drow1_col3" class="data row1 col3" ><a target="_blank" href="https://github.com/jupyterhub/binderhub/pull/780">https://github.com/jupyterhub/binderhub/pull/780</a></td>
#             </tr>
#             <tr>
#                                 <td id="T_8eafa80e_3400_11e9_a32f_54ee75e0f62drow2_col0" class="data row2 col0" >captainsafia</td>
#                         <td id="T_8eafa80e_3400_11e9_a32f_54ee75e0f62drow2_col1" class="data row2 col1" >MEMBER</td>
#                         <td id="T_8eafa80e_3400_11e9_a32f_54ee75e0f62drow2_col2" class="data row2 col2" >0</td>
#                         <td id="T_8eafa80e_3400_11e9_a32f_54ee75e0f62drow2_col3" class="data row2 col3" ><a target="_blank" href="https://github.com/jupyterhub/binderhub/pull/778">https://github.com/jupyterhub/binderhub/pull/778</a></td>
#             </tr>
#             <tr>
#                                 <td id="T_8eafa80e_3400_11e9_a32f_54ee75e0f62drow3_col0" class="data row3 col0" >choldgraf</td>
#                         <td id="T_8eafa80e_3400_11e9_a32f_54ee75e0f62drow3_col1" class="data row3 col1" >MEMBER</td>
#                         <td id="T_8eafa80e_3400_11e9_a32f_54ee75e0f62drow3_col2" class="data row3 col2" >1</td>
#                         <td id="T_8eafa80e_3400_11e9_a32f_54ee75e0f62drow3_col3" class="data row3 col3" ><a target="_blank" href="https://github.com/jupyterhub/binderhub/pull/792">https://github.com/jupyterhub/binderhub/pull/792</a></td>
#             </tr>
#             <tr>
#                                 <td id="T_8eafa80e_3400_11e9_a32f_54ee75e0f62drow4_col0" class="data row4 col0" >choldgraf</td>
#                         <td id="T_8eafa80e_3400_11e9_a32f_54ee75e0f62drow4_col1" class="data row4 col1" >MEMBER</td>
#                         <td id="T_8eafa80e_3400_11e9_a32f_54ee75e0f62drow4_col2" class="data row4 col2" >1</td>
#                         <td id="T_8eafa80e_3400_11e9_a32f_54ee75e0f62drow4_col3" class="data row4 col3" ><a target="_blank" href="https://github.com/jupyterhub/binderhub/pull/791">https://github.com/jupyterhub/binderhub/pull/791</a></td>
#             </tr>
#             <tr>
#                                 <td id="T_8eafa80e_3400_11e9_a32f_54ee75e0f62drow5_col0" class="data row5 col0" >betatim</td>
#                         <td id="T_8eafa80e_3400_11e9_a32f_54ee75e0f62drow5_col1" class="data row5 col1" >MEMBER</td>
#                         <td id="T_8eafa80e_3400_11e9_a32f_54ee75e0f62drow5_col2" class="data row5 col2" >1</td>
#                         <td id="T_8eafa80e_3400_11e9_a32f_54ee75e0f62drow5_col3" class="data row5 col3" ><a target="_blank" href="https://github.com/jupyterhub/binderhub/pull/773">https://github.com/jupyterhub/binderhub/pull/773</a></td>
#             </tr>
#             <tr>
#                                 <td id="T_8eafa80e_3400_11e9_a32f_54ee75e0f62drow6_col0" class="data row6 col0" >bitnik</td>
#                         <td id="T_8eafa80e_3400_11e9_a32f_54ee75e0f62drow6_col1" class="data row6 col1" >CONTRIBUTOR</td>
#                         <td id="T_8eafa80e_3400_11e9_a32f_54ee75e0f62drow6_col2" class="data row6 col2" >1</td>
#                         <td id="T_8eafa80e_3400_11e9_a32f_54ee75e0f62drow6_col3" class="data row6 col3" ><a target="_blank" href="https://github.com/jupyterhub/binderhub/pull/771">https://github.com/jupyterhub/binderhub/pull/771</a></td>
#             </tr>
#             <tr>
#                                 <td id="T_8eafa80e_3400_11e9_a32f_54ee75e0f62drow7_col0" class="data row7 col0" >minrk</td>
#                         <td id="T_8eafa80e_3400_11e9_a32f_54ee75e0f62drow7_col1" class="data row7 col1" >MEMBER</td>
#                         <td id="T_8eafa80e_3400_11e9_a32f_54ee75e0f62drow7_col2" class="data row7 col2" >1</td>
#                         <td id="T_8eafa80e_3400_11e9_a32f_54ee75e0f62drow7_col3" class="data row7 col3" ><a target="_blank" href="https://github.com/jupyterhub/binderhub/pull/790">https://github.com/jupyterhub/binderhub/pull/790</a></td>
#             </tr>
#             <tr>
#                                 <td id="T_8eafa80e_3400_11e9_a32f_54ee75e0f62drow8_col0" class="data row8 col0" >captainsafia</td>
#                         <td id="T_8eafa80e_3400_11e9_a32f_54ee75e0f62drow8_col1" class="data row8 col1" >MEMBER</td>
#                         <td id="T_8eafa80e_3400_11e9_a32f_54ee75e0f62drow8_col2" class="data row8 col2" >1</td>
#                         <td id="T_8eafa80e_3400_11e9_a32f_54ee75e0f62drow8_col3" class="data row8 col3" ><a target="_blank" href="https://github.com/jupyterhub/binderhub/pull/779">https://github.com/jupyterhub/binderhub/pull/779</a></td>
#             </tr>
#             <tr>
#                                 <td id="T_8eafa80e_3400_11e9_a32f_54ee75e0f62drow9_col0" class="data row9 col0" >minrk</td>
#                         <td id="T_8eafa80e_3400_11e9_a32f_54ee75e0f62drow9_col1" class="data row9 col1" >MEMBER</td>
#                         <td id="T_8eafa80e_3400_11e9_a32f_54ee75e0f62drow9_col2" class="data row9 col2" >1</td>
#                         <td id="T_8eafa80e_3400_11e9_a32f_54ee75e0f62drow9_col3" class="data row9 col3" ><a target="_blank" href="https://github.com/jupyterhub/binderhub/pull/783">https://github.com/jupyterhub/binderhub/pull/783</a></td>
#             </tr>
#             <tr>
#                                 <td id="T_8eafa80e_3400_11e9_a32f_54ee75e0f62drow10_col0" class="data row10 col0" >bitnik</td>
#                         <td id="T_8eafa80e_3400_11e9_a32f_54ee75e0f62drow10_col1" class="data row10 col1" >CONTRIBUTOR</td>
#                         <td id="T_8eafa80e_3400_11e9_a32f_54ee75e0f62drow10_col2" class="data row10 col2" >2</td>
#                         <td id="T_8eafa80e_3400_11e9_a32f_54ee75e0f62drow10_col3" class="data row10 col3" ><a target="_blank" href="https://github.com/jupyterhub/binderhub/pull/775">https://github.com/jupyterhub/binderhub/pull/775</a></td>
#             </tr>
#             <tr>
#                                 <td id="T_8eafa80e_3400_11e9_a32f_54ee75e0f62drow11_col0" class="data row11 col0" >choldgraf</td>
#                         <td id="T_8eafa80e_3400_11e9_a32f_54ee75e0f62drow11_col1" class="data row11 col1" >MEMBER</td>
#                         <td id="T_8eafa80e_3400_11e9_a32f_54ee75e0f62drow11_col2" class="data row11 col2" >3</td>

# %% [markdown]
# # State of repo
#
# ## Stale issues

# %%
stale_issues = issues.query('updated_at < @date_stale')
stale_issues = stale_issues[stale_issues['closed_at'].isnull()]

# %%
stale_issues[['user', 'author_association', 'comments', 'html_url']]\
    .sort_values(['comments']).style.applymap(highlight_rows).format({'html_url': make_clickable}).hide_index()
# Out:
# <style  type="text/css" >
#     #T_8f0d524c_3400_11e9_a32f_54ee75e0f62drow0_col2 {
#             background-color:  #f7b7b7;
#         }    #T_8f0d524c_3400_11e9_a32f_54ee75e0f62drow1_col2 {
#             background-color:  #f7b7b7;
#         }    #T_8f0d524c_3400_11e9_a32f_54ee75e0f62drow2_col1 {
#             background-color:  #f7b7b7;
#         }    #T_8f0d524c_3400_11e9_a32f_54ee75e0f62drow2_col2 {
#             background-color:  #f7b7b7;
#         }    #T_8f0d524c_3400_11e9_a32f_54ee75e0f62drow3_col2 {
#             background-color:  #f7b7b7;
#         }    #T_8f0d524c_3400_11e9_a32f_54ee75e0f62drow4_col2 {
#             background-color:  #f7b7b7;
#         }    #T_8f0d524c_3400_11e9_a32f_54ee75e0f62drow5_col1 {
#             background-color:  #f7b7b7;
#         }    #T_8f0d524c_3400_11e9_a32f_54ee75e0f62drow5_col2 {
#             background-color:  #f7b7b7;
#         }    #T_8f0d524c_3400_11e9_a32f_54ee75e0f62drow6_col2 {
#             background-color:  #f7b7b7;
#         }    #T_8f0d524c_3400_11e9_a32f_54ee75e0f62drow7_col2 {
#             background-color:  #f7b7b7;
#         }    #T_8f0d524c_3400_11e9_a32f_54ee75e0f62drow8_col2 {
#             background-color:  #f7b7b7;
#         }    #T_8f0d524c_3400_11e9_a32f_54ee75e0f62drow9_col2 {
#             background-color:  #f7b7b7;
#         }    #T_8f0d524c_3400_11e9_a32f_54ee75e0f62drow10_col2 {
#             background-color:  #f7b7b7;
#         }    #T_8f0d524c_3400_11e9_a32f_54ee75e0f62drow11_col2 {
#             background-color:  #f7b7b7;
#         }    #T_8f0d524c_3400_11e9_a32f_54ee75e0f62drow12_col2 {
#             background-color:  #f7b7b7;
#         }    #T_8f0d524c_3400_11e9_a32f_54ee75e0f62drow13_col2 {
#             background-color:  #f7b7b7;
#         }    #T_8f0d524c_3400_11e9_a32f_54ee75e0f62drow14_col2 {
#             background-color:  #f7b7b7;
#         }    #T_8f0d524c_3400_11e9_a32f_54ee75e0f62drow15_col2 {
#             background-color:  #f7b7b7;
#         }    #T_8f0d524c_3400_11e9_a32f_54ee75e0f62drow16_col2 {
#             background-color:  #f7b7b7;
#         }    #T_8f0d524c_3400_11e9_a32f_54ee75e0f62drow17_col1 {
#             background-color:  #f7b7b7;
#         }    #T_8f0d524c_3400_11e9_a32f_54ee75e0f62drow17_col2 {
#             background-color:  #f7b7b7;
#         }    #T_8f0d524c_3400_11e9_a32f_54ee75e0f62drow18_col2 {
#             background-color:  #f7b7b7;
#         }    #T_8f0d524c_3400_11e9_a32f_54ee75e0f62drow19_col2 {
#             background-color:  #f7b7b7;
#         }    #T_8f0d524c_3400_11e9_a32f_54ee75e0f62drow20_col2 {
#             background-color:  #f7b7b7;
#         }    #T_8f0d524c_3400_11e9_a32f_54ee75e0f62drow21_col2 {
#             background-color:  #f7b7b7;
#         }    #T_8f0d524c_3400_11e9_a32f_54ee75e0f62drow22_col2 {
#             background-color:  #f7b7b7;
#         }    #T_8f0d524c_3400_11e9_a32f_54ee75e0f62drow23_col2 {
#             background-color:  #f7b7b7;
#         }    #T_8f0d524c_3400_11e9_a32f_54ee75e0f62drow24_col2 {
#             background-color:  #f7b7b7;
#         }    #T_8f0d524c_3400_11e9_a32f_54ee75e0f62drow25_col2 {
#             background-color:  #f7b7b7;
#         }    #T_8f0d524c_3400_11e9_a32f_54ee75e0f62drow26_col2 {
#             background-color:  #f7b7b7;
#         }    #T_8f0d524c_3400_11e9_a32f_54ee75e0f62drow27_col2 {
#             background-color:  #f7b7b7;
#         }    #T_8f0d524c_3400_11e9_a32f_54ee75e0f62drow28_col2 {
#             background-color:  #f7b7b7;
#         }    #T_8f0d524c_3400_11e9_a32f_54ee75e0f62drow33_col1 {
#             background-color:  #f7b7b7;
#         }    #T_8f0d524c_3400_11e9_a32f_54ee75e0f62drow44_col1 {
#             background-color:  #f7b7b7;
#         }    #T_8f0d524c_3400_11e9_a32f_54ee75e0f62drow54_col1 {
#             background-color:  #f7b7b7;
#         }    #T_8f0d524c_3400_11e9_a32f_54ee75e0f62drow58_col1 {
#             background-color:  #f7b7b7;
#         }    #T_8f0d524c_3400_11e9_a32f_54ee75e0f62drow61_col1 {
#             background-color:  #f7b7b7;
#         }    #T_8f0d524c_3400_11e9_a32f_54ee75e0f62drow62_col1 {
#             background-color:  #f7b7b7;
#         }    #T_8f0d524c_3400_11e9_a32f_54ee75e0f62drow65_col1 {
#             background-color:  #f7b7b7;
#         }    #T_8f0d524c_3400_11e9_a32f_54ee75e0f62drow67_col1 {
#             background-color:  #f7b7b7;
#         }    #T_8f0d524c_3400_11e9_a32f_54ee75e0f62drow69_col1 {
#             background-color:  #f7b7b7;
#         }    #T_8f0d524c_3400_11e9_a32f_54ee75e0f62drow73_col1 {
#             background-color:  #f7b7b7;
#         }    #T_8f0d524c_3400_11e9_a32f_54ee75e0f62drow74_col1 {
#             background-color:  #f7b7b7;
#         }    #T_8f0d524c_3400_11e9_a32f_54ee75e0f62drow82_col1 {
#             background-color:  #f7b7b7;
#         }    #T_8f0d524c_3400_11e9_a32f_54ee75e0f62drow89_col1 {
#             background-color:  #f7b7b7;
#         }    #T_8f0d524c_3400_11e9_a32f_54ee75e0f62drow90_col1 {
#             background-color:  #f7b7b7;
#         }    #T_8f0d524c_3400_11e9_a32f_54ee75e0f62drow96_col1 {
#             background-color:  #f7b7b7;
#         }    #T_8f0d524c_3400_11e9_a32f_54ee75e0f62drow104_col1 {
#             background-color:  #f7b7b7;
#         }    #T_8f0d524c_3400_11e9_a32f_54ee75e0f62drow106_col1 {
#             background-color:  #f7b7b7;
#         }    #T_8f0d524c_3400_11e9_a32f_54ee75e0f62drow107_col1 {
#             background-color:  #f7b7b7;
#         }    #T_8f0d524c_3400_11e9_a32f_54ee75e0f62drow110_col1 {
#             background-color:  #f7b7b7;
#         }    #T_8f0d524c_3400_11e9_a32f_54ee75e0f62drow112_col1 {
#             background-color:  red;
#         }    #T_8f0d524c_3400_11e9_a32f_54ee75e0f62drow116_col1 {
#             background-color:  red;
#         }    #T_8f0d524c_3400_11e9_a32f_54ee75e0f62drow119_col1 {
#             background-color:  #f7b7b7;
#         }    #T_8f0d524c_3400_11e9_a32f_54ee75e0f62drow122_col1 {
#             background-color:  #f7b7b7;
#         }    #T_8f0d524c_3400_11e9_a32f_54ee75e0f62drow123_col1 {
#             background-color:  #f7b7b7;
#         }    #T_8f0d524c_3400_11e9_a32f_54ee75e0f62drow136_col1 {
#             background-color:  #f7b7b7;
#         }    #T_8f0d524c_3400_11e9_a32f_54ee75e0f62drow142_col1 {
#             background-color:  #f7b7b7;
#         }    #T_8f0d524c_3400_11e9_a32f_54ee75e0f62drow146_col1 {
#             background-color:  #f7b7b7;
#         }    #T_8f0d524c_3400_11e9_a32f_54ee75e0f62drow150_col1 {
#             background-color:  #f7b7b7;
#         }</style><table id="T_8f0d524c_3400_11e9_a32f_54ee75e0f62d" ><thead>    <tr>        <th class="col_heading level0 col0" >user</th>        <th class="col_heading level0 col1" >author_association</th>        <th class="col_heading level0 col2" >comments</th>        <th class="col_heading level0 col3" >html_url</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_8f0d524c_3400_11e9_a32f_54ee75e0f62drow0_col0" class="data row0 col0" >minrk</td>
#                         <td id="T_8f0d524c_3400_11e9_a32f_54ee75e0f62drow0_col1" class="data row0 col1" >MEMBER</td>
#                         <td id="T_8f0d524c_3400_11e9_a32f_54ee75e0f62drow0_col2" class="data row0 col2" >0</td>
#                         <td id="T_8f0d524c_3400_11e9_a32f_54ee75e0f62drow0_col3" class="data row0 col3" ><a target="_blank" href="https://github.com/jupyterhub/binderhub/issues/464">https://github.com/jupyterhub/binderhub/issues/464</a></td>
#             </tr>
#             <tr>
#                                 <td id="T_8f0d524c_3400_11e9_a32f_54ee75e0f62drow1_col0" class="data row1 col0" >choldgraf</td>
#                         <td id="T_8f0d524c_3400_11e9_a32f_54ee75e0f62drow1_col1" class="data row1 col1" >MEMBER</td>
#                         <td id="T_8f0d524c_3400_11e9_a32f_54ee75e0f62drow1_col2" class="data row1 col2" >0</td>
#                         <td id="T_8f0d524c_3400_11e9_a32f_54ee75e0f62drow1_col3" class="data row1 col3" ><a target="_blank" href="https://github.com/jupyterhub/binderhub/issues/238">https://github.com/jupyterhub/binderhub/issues/238</a></td>
#             </tr>
#             <tr>
#                                 <td id="T_8f0d524c_3400_11
