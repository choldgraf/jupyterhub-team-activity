# %%
import pandas as pd
from subprocess import run, PIPE
from watchtower import comments_, issues_, commits_, reviews_
from glob import glob
import os.path as op
import shutil as sh
import os
auth = os.environ['GITHUB_API_TOKEN']

# %% [markdown]
# ## Collect and save team membership info

# %%
from ruamel.yaml import YAML
from requests import get

url_jupyterhub = "https://raw.githubusercontent.com/jupyterhub/team-compass/master/docs/team/contributors-jupyterhub.yaml"
url_binder = "https://raw.githubusercontent.com/jupyterhub/team-compass/master/docs/team/contributors-binder.yaml"

yaml = YAML()
jupyterhub_team = yaml.load(get(url_jupyterhub).text)
binder_team = yaml.load(get(url_binder).text)

# %%
data = []
for ii in jupyterhub_team:
    data.append({'name': ii['name'], 'username': ii['handle'].strip('@'), 'team': 'jupyterhub'})
    
for ii in binder_team:
    data.append({'name': ii['name'], 'username': ii['handle'].strip('@'), 'team': ii['team']})

# %%
teams = pd.DataFrame(data)
teams.to_csv('../data/teams.csv', index=False)

# %% [markdown]
# ## Helper funcs

# %%
def delete_data(org, repo, data_dir=data_folder):
    path_data = op.join(op.expanduser(data_dir), org, repo)
    if op.exists(path_data):
        sh.rmtree(path_data)
        print('Deleted {}/{}'.format(org, repo))
        
def list_data(data_dir=data_folder):
    all_data = []
    for folder in glob(op.join(op.expanduser(data_dir), '*', '*')):
        org, repo = folder.split(op.expanduser(data_dir))[-1].strip(os.sep).split(os.sep)[:2]
        data = comments_.load_comments(org, repo)
        date_col = 'created_at' if 'created_at' in data.columns else 'date'
        data = data[[date_col]].resample('Y', on=date_col).count()
        data['org'] = org
        data['repo'] = repo
        all_data.append(data.rename(columns={'created_at': 'count'}))
    all_data = pd.concat(all_data).set_index(['org', 'repo'], append=True)['count'].unstack('created_at')
    all_data.columns = all_data.columns.year
    return all_data

# %% [markdown]
# ## Update data

# %%
from datetime import timedelta
date = pd.datetime.today() - timedelta(days=30)

# %%
# If we wish to update the data
update_data = True
if update_data is True:
    try:
        for org, repos in projects.items():
            print(org)
            for repo in repos:
                print('    ' + repo)
                run("python ../scripts/update_data.py {} {}".format(org, repo).split(), check=True, stderr=PIPE, stdout=PIPE)
    except Exception as ee:
        print(ee.stderr.decode())
# Out:
# jupyter
#     repo2docker
# jupyterhub
#     zero-to-jupyterhub-k8s
#     the-littlest-jupyterhub
#     jupyterhub
#     binderhub
#     binder
#     team-compass
#     mybinder.org-deploy
#     configurable-http-proxy
#     nativeauthenticator
#     traefik-proxy
#     jupyter-server-proxy

# %% [markdown]
# ## Munge

# %%
repos = list_data()
repos
# Out:
# created_at                          2015    2016    2017    2018   2019
# org        repo
# jupyter    nbconvert                10.0  1665.0  1105.0   799.0   87.0
#            notebook                 16.0  5495.0  2741.0     NaN    NaN
#            repo2docker               NaN     NaN   585.0  1590.0  172.0
# jupyterhub binder                    NaN     NaN   289.0   279.0   12.0
#            binderhub                 NaN     NaN  1310.0  1438.0   91.0
#            configurable-http-proxy   NaN   125.0   109.0    66.0    6.0
#            jupyter-server-proxy      NaN     NaN     9.0   150.0  101.0
#            jupyterhub                NaN  2095.0  2223.0  2383.0  182.0
#            mybinder.org-deploy       NaN     NaN   408.0   987.0   30.0
#            nativeauthenticator       NaN     NaN     NaN    17.0   42.0
#            team-compass              NaN     NaN    15.0   614.0  120.0
#            the-littlest-jupyterhub   NaN     NaN     NaN   608.0   38.0
#            traefik-proxy             NaN     NaN     NaN    34.0   24.0
#            zero-to-jupyterhub-k8s    NaN     NaN  1042.0  2890.0  244.0
# nteract    hydrogen                  NaN  1970.0  1875.0  1190.0  161.0
#            nteract                   NaN  3563.0  3056.0  3381.0    NaN
#            papermill                 NaN     NaN   145.0   629.0  109.0

# %%
i_opened_issues
# Out:
#            org                 repo                date       user
# 12  jupyterhub  mybinder.org-deploy 2019-01-24 08:37:16      minrk
# 14  jupyterhub  mybinder.org-deploy 2019-01-22 13:28:43    betatim
# 5   jupyterhub  mybinder.org-deploy 2019-02-04 16:19:03  choldgraf

# %%
pd.merge(icomments, icommits, on=['user', 'date'], how='outer')
# Out:
#                     user                date  comment  commit
# 0                  minrk 2015-03-17 16:53:25      1.0     NaN
# 1                  minrk 2015-03-17 18:45:43      1.0     NaN
# 2                Carreau 2015-11-12 21:43:36      1.0     NaN
# 3                  minrk 2016-01-21 16:24:36      1.0     NaN
# 4               jdfreder 2016-02-25 02:02:42      1.0     NaN
# 5               jdfreder 2016-02-25 04:39:56      1.0     NaN
# 6              ellisonbg 2016-02-25 04:48:47      1.0     NaN
# 7               sunlizhe 2016-02-25 07:31:54      1.0     NaN
# 8           captainsafia 2016-02-25 08:06:40      1.0     NaN
# 9           captainsafia 2016-02-25 08:41:24      1.0     NaN
# 10               julienr 2016-02-25 09:29:55      1.0     NaN
# 11               julienr 2016-02-25 09:53:37      1.0     NaN
# 12                 minrk 2016-02-25 10:17:35      1.0     NaN
# 13                 minrk 2016-02-25 10:40:55      1.0     NaN
# 14            jasongrout 2016-01-21 16:34:43      1.0     NaN
# 15                 minrk 2016-02-25 10:57:41      1.0     NaN
# 16     michaelsbradleyjr 2016-02-25 11:15:00      1.0     NaN
# 17             takluyver 2016-02-25 12:12:34      1.0     NaN
# 18             takluyver 2016-02-25 12:23:19      1.0     NaN
# 19                 minrk 2016-02-25 12:23:09      1.0     NaN
# 20               parente 2016-02-25 13:16:59      1.0     NaN
# 21                 minrk 2016-02-25 13:27:40      1.0     NaN
# 22               parente 2016-02-25 13:54:32      1.0     NaN
# 23                 minrk 2016-02-25 14:36:23      1.0     NaN
# 24             blink1073 2016-02-25 14:38:30      1.0     NaN
# 25            jasongrout 2016-01-21 16:46:14      1.0     NaN
# 26             blink1073 2016-02-25 15:14:42      1.0     NaN
# 27          captainsafia 2016-02-25 16:27:00      1.0     NaN
# 28             takluyver 2016-02-25 16:36:33      1.0     NaN
# 29            gracehllee 2016-02-25 16:41:11      1.0     NaN
# ...                  ...                 ...      ...     ...
# 17735          yuvipanda 2017-02-24 00:00:00      NaN     0.0
# 17736          yuvipanda 2017-02-25 00:00:00      NaN     0.0
# 17737          yuvipanda 2017-02-26 00:00:00      NaN     0.0
# 17738          yuvipanda 2017-02-27 00:00:00      NaN     0.0
# 17739          yuvipanda 2017-02-28 00:00:00      NaN     0.0
# 17740          yuvipanda 2017-03-01 00:00:00      NaN     0.0
# 17741          yuvipanda 2017-03-02 00:00:00      NaN     0.0
# 17742          yuvipanda 2017-03-03 00:00:00      NaN     0.0
# 17743          yuvipanda 2017-03-04 00:00:00      NaN     0.0
# 17744          yuvipanda 2017-03-05 00:00:00      NaN     2.0
# 17745          zasdfgbnm 2017-01-18 00:00:00      NaN     3.0
# 17746          zasdfgbnm 2017-01-19 00:00:00      NaN     1.0
# 17747          zasdfgbnm 2017-01-20 00:00:00      NaN     0.0
# 17748          zasdfgbnm 2017-01-21 00:00:00      NaN     0.0
# 17749          zasdfgbnm 2017-01-22 00:00:00      NaN     0.0
# 17750          zasdfgbnm 2017-01-23 00:00:00      NaN     0.0
# 17751          zasdfgbnm 2017-01-24 00:00:00      NaN     0.0
# 17752          zasdfgbnm 2017-01-25 00:00:00      NaN     0.0
# 17753          zasdfgbnm 2017-01-26 00:00:00      NaN     0.0
# 17754          zasdfgbnm 2017-01-27 00:00:00      NaN     0.0
# 17755          zasdfgbnm 2017-01-28 00:00:00      NaN     0.0
# 17756          zasdfgbnm 2017-01-29 00:00:00      NaN     0.0
# 17757          zasdfgbnm 2017-01-30 00:00:00      NaN     0.0
# 17758          zasdfgbnm 2017-01-31 00:00:00      NaN     0.0
# 17759          zasdfgbnm 2017-02-01 00:00:00      NaN     0.0
# 17760          zasdfgbnm 2017-02-02 00:00:00      NaN     0.0
# 17761          zasdfgbnm 2017-02-03 00:00:00      NaN     0.0
# 17762          zasdfgbnm 2017-02-04 00:00:00      NaN     0.0
# 17763          zasdfgbnm 2017-02-05 00:00:00      NaN     0.0
# 17764          zasdfgbnm 2017-02-06 00:00:00      NaN     3.0
#
# [17765 rows x 4 columns]

# %%
data = pd.DataFrame([])

for org, repo in repos.index:
    print('{}/{}'.format(org, repo))
    # Comments
    icomments = comments_.load_comments(org, repo)
    if icomments is not None:
        icomments['user'] = icomments['user'].map(lambda a: a['login'])
        icomments['date'] = icomments['created_at'].map(pd.to_datetime)
        icomments = icomments[['user', 'date']]
        icomments['comment'] = 1
        icomments = icomments.groupby(['user']).resample('D', on='date').sum().reset_index()
        
    # Commits
    icommits = commits_.load_commits(org, repo)
    if icommits is not None:
        icommits = icommits.dropna(subset=['author'])
        icommits['user'] = icommits['author'].map(lambda a: a['login'])
        icommits['date'] = pd.to_datetime(icommits['date'])
        icommits = icommits[['date', 'user']]
        icommits['commit'] = 1
        icommits = icommits.groupby(['user']).resample('D', on='date').sum().reset_index()
    
    # Issues
    issues = issues_.load_issues(org, repo)
    if issues is not None:
        issues['user'] = issues['user'].map(lambda a: a['login'])
        
        # Extract PRs vs Issues
        prs = issues[issues['pull_request'].values != None]
        issues = issues[issues['pull_request'].values == None]

        # Calculate the opened and losed issues
        i_opened_issues = issues.query('created_at > @date')
        i_closed_issues = issues.query('closed_at > @date')

        i_opened_issues = i_opened_issues.rename(columns={'created_at': 'date'})
        i_closed_issues = i_closed_issues.rename(columns={'closed_at': 'date'})

        # Calculate the opened and closed PRs
        i_opened_prs = prs.query('created_at > @date').rename(columns={'created_at': 'date'})
        i_closed_prs = prs.query('closed_at > @date').rename(columns={'closed_at': 'date'})

        # Pull only the fields we want and add identifying column
        i_opened_prs = i_opened_prs[['date', 'user']]
        i_opened_prs['opened_pr'] = 1
        i_opened_prs = i_opened_prs.groupby(['user']).resample('D', on='date').sum().reset_index()
        
        i_closed_prs = i_closed_prs[['date', 'user']]
        i_closed_prs['closed_pr'] = 1
        i_closed_prs = i_closed_prs.groupby(['user']).resample('D', on='date').sum().reset_index()
        
        i_opened_issues = i_opened_issues[['date', 'user']]
        i_opened_prs['opened_issue'] = 1
        i_opened_prs = i_opened_prs.groupby(['user']).resample('D', on='date').sum().reset_index()
        
        i_closed_issues = i_closed_issues[['date', 'user']]
        i_opened_prs['closed_issue'] = 1
        i_opened_prs = i_opened_prs.groupby(['user']).resample('D', on='date').sum().reset_index()
# Out:
# jupyter/nbconvert
# jupyter/notebook
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-80-ebc49ce5aaad> in <module>()
#      10         icomments = icomments[['user', 'date']]
#      11         icomments['comment'] = 1
# ---> 12         icomments = icomments.groupby(['user']).resample('D', on='date').sum().reset_index()
#      13
#      14     # Commits
#
# ~/anaconda/envs/dev/lib/python3.6/site-packages/pandas/core/resample.py in f(self, _method, min_count, *args, **kwargs)
#     756     def f(self, _method=method, min_count=0, *args, **kwargs):
#     757         nv.validate_resampler_func(_method, args, kwargs)
# --> 758         return self._downsample(_method, min_count=min_count)
#     759     f.__doc__ = getattr(GroupBy, method).__doc__
#     760     setattr(Resampler, method, f)
#
# ~/anaconda/envs/dev/lib/python3.6/site-packages/pandas/core/resample.py in _apply(self, f, **kwargs)
#     867             return x.apply(f, **kwargs)
#     868
# --> 869         result = self._groupby.apply(func)
#     870         return self._wrap_result(result)
#     871
#
# ~/anaconda/envs/dev/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in apply(self, func, *args, **kwargs)
#     916         with option_context('mode.chained_assignment', None):
#     917             try:
# --> 918                 result = self._python_apply_general(f)
#     919             except Exception:
#     920
#
# ~/anaconda/envs/dev/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in _python_apply_general(self, f)
#     934     def _python_apply_general(self, f):
#     935         keys, values, mutated = self.grouper.apply(f, self._selected_obj,
# --> 936                                                    self.axis)
#     937
#     938         return self._wrap_applied_output(
#
# ~/anaconda/envs/dev/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in apply(self, f, data, axis)
#    2255                 hasattr(splitter, 'fast_apply') and axis == 0):
#    2256             try:
# -> 2257                 values, mutated = splitter.fast_apply(f, group_keys)
#    2258                 return group_keys, values, mutated
#    2259             except reduction.InvalidApply:
#
# ~/anaconda/envs/dev/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in fast_apply(self, f, names)
#    5088         sdata = self._get_sorted_data()
#    5089         results, mutated = reduction.apply_frame_axis0(sdata, f, names,
# -> 5090                                                        starts, ends)
#    5091
#    5092         return results, mutated
#
# pandas/_libs/reduction.pyx in pandas._libs.reduction.apply_frame_axis0()
#
# ~/anaconda/envs/dev/lib/python3.6/site-packages/pandas/core/resample.py in func(x)
#     863
#     864             if isinstance(f, compat.string_types):
# --> 865                 return getattr(x, f)(**kwargs)
#     866
#     867             return x.apply(f, **kwargs)
#
# ~/anaconda/envs/dev/lib/python3.6/site-packages/pandas/core/resample.py in f(self, _method, min_count, *args, **kwargs)
#     756     def f(self, _method=method, min_count=0, *args, **kwargs):
#     757         nv.validate_resampler_func(_method, args, kwargs)
# --> 758         return self._downsample(_method, min_count=min_count)
#     759     f.__doc__ = getattr(GroupBy, method).__doc__
#     760     setattr(Resampler, method, f)
#
# ~/anaconda/envs/dev/lib/python3.6/site-packages/pandas/core/resample.py in _downsample(self, how, **kwargs)
#     897         **kwargs : kw args passed to how function
#     898         """
# --> 899         self._set_binner()
#     900         how = self._is_cython_func(how) or how
#     901         ax = self.ax
#
# ~/anaconda/envs/dev/lib/python3.6/site-packages/pandas/core/resample.py in _set_binner(self)
#     146
#     147         if self.binner is None:
# --> 148             self.binner, self.grouper = self._get_binner()
#     149
#     150     def _get_binner(self):
#
# ~/anaconda/envs/dev/lib/python3.6/site-packages/pandas/core/resample.py in _get_binner(self)
#     154         """
#     155
# --> 156         binner, bins, binlabels = self._get_binner_for_time()
#     157         bin_grouper = BinGrouper(bins, binlabels, indexer=self.groupby.indexer)
#     158         return binner, bin_grouper
#
# ~/anaconda/envs/dev/lib/python3.6/site-packages/pandas/core/resample.py in _get_binner_for_time(self)
#     886         if self.kind == 'period':
#     887             return self.groupby._get_time_period_bins(self.ax)
# --> 888         return self.groupby._get_time_bins(self.ax)
#     889
#     890     def _downsample(self, how, **kwargs):
#
# ~/anaconda/envs/dev/lib/python3.6/site-packages/pandas/core/resample.py in _get_time_bins(self, ax)
#    1306                                         end=last,
#    1307                                         tz=tz,
# -> 1308                                         name=ax.name)
#    1309
#    1310         # GH 15549
#
# ~/anaconda/envs/dev/lib/python3.6/site-packages/pandas/core/indexes/datetimes.py in __new__(cls, data, freq, start, end, periods, tz, normalize, closed, ambiguous, dayfirst, yearfirst, dtype, copy, name, verify_integrity)
#     379                 return cls._generate(start, end, periods, name, freq, tz=tz,
#     380                                      normalize=normalize, closed=closed,
# --> 381                                      ambiguous=ambiguous)
#     382
#     383         if not isinstance(data, (np.ndarray, Index, ABCSeries)):
#
# ~/anaconda/envs/dev/lib/python3.6/site-packages/pandas/core/indexes/datetimes.py in _generate(cls, start, end, periods, name, freq, tz, normalize, ambiguous, closed)
#     528                 _normalized = _normalized and end.time() == _midnight
#     529
# --> 530         if hasattr(freq, 'delta') and freq != offsets.Day():
#     531             if inferred_tz is None and tz is not None:
#     532                 # naive dates
#
# ~/anaconda/envs/dev/lib/python3.6/site-packages/pandas/tseries/offsets.py in __ne__(self, other)
#    2264
#    2265         if isinstance(other, Tick):
# -> 2266             return self.delta != other.delta
#    2267         else:
#    2268             # TODO: Are there cases where this should raise TypeError?
#
# ~/anaconda/envs/dev/lib/python3.6/site-packages/pandas/tseries/offsets.py in delta(self)
#    2271     @property
#    2272     def delta(self):
# -> 2273         return self.n * self._inc
#    2274
#    2275     @property
#
# pandas/_libs/tslibs/timedeltas.pyx in pandas._libs.tslibs.timedeltas.Timedelta.__mul__()
#
# pandas/_libs/tslibs/timedeltas.pyx in pandas._libs.tslibs.timedeltas.Timedelta.__new__()
#
# pandas/_libs/tslibs/timedeltas.pyx in pandas._libs.tslibs.timedeltas.convert_to_timedelta64()
#
# pandas/_libs/tslibs/timedeltas.pyx in pandas._libs.tslibs.timedeltas.cast_from_unit()
#
# KeyboardInterrupt:

# %% [markdown]
# ## Convert into daily and combine

# %%
# Convert into daily comments/commits to reduce size
daily_comments = comments.groupby(['org', 'repo', 'user']).resample('D').sum().dropna()
daily_comments = daily_comments.reset_index().query('count != 0')
daily_comments = daily_comments.rename(columns={'count': 'comments'})

# %%
# Daily commits
daily_commits = commits.groupby(['org', 'repo', 'user']).resample('D').sum().dropna()
daily_commits = daily_commits.reset_index().query('count != 0')
daily_commits = daily_commits.rename(columns={'count': 'commits'})

# %%
# Merge them and save
daily = pd.merge(daily_commits, daily_comments, on=['org', 'repo', 'user', 'date'], how='outer')
daily.to_csv('../data/daily.csv')
